# %% [markdown]
# ## 1. Import Libraries

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## 2. Neural Newtork Architecture

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))


model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))



model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(1024, activation="relu"))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              4195328
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 5,946,954
# Trainable params: 5,944,010
# Non-trainable params: 2,944
# _________________________________________________________________

# %% [markdown]
# ## 3. Cost function

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Data Preparation
#
# We load the CIFAR10 dataset directly from Keras. Those are already split in train and test.
#
#
# **Important:**
# > The neural network requires for the inputs to be real numbers. We can simply achieve this by divinding the values inside the matrices by 255.0.

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %%
# Let's plot a sample of the images

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# When we add convolutions, we need to preprocess the data, because **convolution is for an array of 4 fields** (more like "images"), not an array of 3 dimensions as the datasets for train, test and validation. So we need to **.reshape()**.
#
# That's why, when you exit the convolution, you have to flatten the matrices, because the FullDense layers expect arrays, not matrices!

# %%
# Let's validate the results
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# # 4. Early Stopping

# %%
callback_loss = EarlyStopping(monitor="val_loss", patience=15)
callback_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)

# %%
checkpoint_filepath = '/tmp/checkpoint'
model_checkpoint_callback = ks.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %% [markdown]
# ## 5. Training
#
# Note that we have to train against the data converted to the format expected by the Convolution.
#
# We will start with 30 epochs, that is to say, 30 complete passes of the dataset (which in turn will be with mini-batches internally, setting the batches to 64 elements.
#
# The .fit() method allows us to define if we have several CPUs, GPUs, and if we want to validate data at each end of epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, 
                    epochs=300, 
                    use_multiprocessing=False, 
                    batch_size= 512, 
                    callbacks=[callback_accuracy, callback_loss, model_checkpoint_callback],
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/300
# 79/79 [==============================] - 17s 136ms/step - loss: 2.2144 - accuracy: 0.3097 - val_loss: 5.1905 - val_accuracy: 0.1009
# Epoch 2/300
# 79/79 [==============================] - 9s 116ms/step - loss: 1.6011 - accuracy: 0.4487 - val_loss: 7.3806 - val_accuracy: 0.1004
# Epoch 3/300
# 79/79 [==============================] - 9s 116ms/step - loss: 1.3844 - accuracy: 0.5290 - val_loss: 6.5579 - val_accuracy: 0.1031
# Epoch 4/300
# 79/79 [==============================] - 9s 117ms/step - loss: 1.2444 - accuracy: 0.5692 - val_loss: 4.3847 - val_accuracy: 0.1727
# Epoch 5/300
# 79/79 [==============================] - 9s 117ms/step - loss: 1.0901 - accuracy: 0.6231 - val_loss: 3.8507 - val_accuracy: 0.2131
# Epoch 6/300
# 79/79 [==============================] - 9s 118ms/step - loss: 0.9956 - accuracy: 0.6537 - val_loss: 2.3082 - val_accuracy: 0.3579
# Epoch 7/300
# 79/79 [==============================] - 9s 118ms/step - loss: 0.9206 - accuracy: 0.6811 - val_loss: 1.1741 - val_accuracy: 0.5974
# Epoch 8/300
# 79/79 [==============================] - 9s 118ms/step - loss: 0.8519 - accuracy: 0.7042 - val_loss: 1.1204 - val_accuracy: 0.6141
# Epoch 9/300
# 79/79 [==============================] - 9s 119ms/step - loss: 0.7789 - accuracy: 0.7290 - val_loss: 0.8122 - val_accuracy: 0.7284
# Epoch 10/300
# 79/79 [==============================] - 9s 119ms/step - loss: 0.7310 - accuracy: 0.7469 - val_loss: 0.8513 - val_accuracy: 0.7165
# Epoch 11/300
# 79/79 [==============================] - 9s 119ms/step - loss: 0.6970 - accuracy: 0.7570 - val_loss: 0.7090 - val_accuracy: 0.7604
# Epoch 12/300
# 79/79 [==============================] - 9s 120ms/step - loss: 0.6514 - accuracy: 0.7684 - val_loss: 0.7743 - val_accuracy: 0.7429
# Epoch 13/300
# 79/79 [==============================] - 9s 120ms/step - loss: 0.6027 - accuracy: 0.7886 - val_loss: 0.6725 - val_accuracy: 0.7770
# Epoch 14/300
# 79/79 [==============================] - 9s 120ms/step - loss: 0.5700 - accuracy: 0.8012 - val_loss: 0.7108 - val_accuracy: 0.7783
# Epoch 15/300
# 79/79 [==============================] - 10s 120ms/step - loss: 0.5492 - accuracy: 0.8055 - val_loss: 0.6235 - val_accuracy: 0.7911
# Epoch 16/300
# 79/79 [==============================] - 10s 121ms/step - loss: 0.5072 - accuracy: 0.8195 - val_loss: 0.6737 - val_accuracy: 0.7801
# Epoch 17/300
# 79/79 [==============================] - 10s 121ms/step - loss: 0.4989 - accuracy: 0.8247 - val_loss: 0.6864 - val_accuracy: 0.7723
# Epoch 18/300
# 79/79 [==============================] - 10s 121ms/step - loss: 0.4778 - accuracy: 0.8306 - val_loss: 0.6624 - val_accuracy: 0.7916
# Epoch 19/300
# 79/79 [==============================] - 10s 121ms/step - loss: 0.4386 - accuracy: 0.8440 - val_loss: 0.5537 - val_accuracy: 0.8137
# Epoch 20/300
# 79/79 [==============================] - 10s 122ms/step - loss: 0.4169 - accuracy: 0.8528 - val_loss: 0.5461 - val_accuracy: 0.8200
# Epoch 21/300
# 79/79 [==============================] - 10s 122ms/step - loss: 0.3950 - accuracy: 0.8592 - val_loss: 0.6056 - val_accuracy: 0.8089
# Epoch 22/300
# 79/79 [==============================] - 10s 122ms/step - loss: 0.3752 - accuracy: 0.8654 - val_loss: 0.5748 - val_accuracy: 0.8170
# Epoch 23/300
# 79/79 [==============================] - 10s 122ms/step - loss: 0.3660 - accuracy: 0.8692 - val_loss: 0.5017 - val_accuracy: 0.8321
# Epoch 24/300
# 79/79 [==============================] - 10s 122ms/step - loss: 0.3454 - accuracy: 0.8766 - val_loss: 0.5516 - val_accuracy: 0.8249
# Epoch 25/300
# 79/79 [==============================] - 10s 122ms/step - loss: 0.3327 - accuracy: 0.8801 - val_loss: 0.5638 - val_accuracy: 0.8268
# Epoch 26/300
# 79/79 [==============================] - 10s 123ms/step - loss: 0.3210 - accuracy: 0.8873 - val_loss: 0.5904 - val_accuracy: 0.8186
# Epoch 27/300
# 79/79 [==============================] - 10s 123ms/step - loss: 0.3034 - accuracy: 0.8912 - val_loss: 0.5672 - val_accuracy: 0.8246
# Epoch 28/300
# 79/79 [==============================] - 10s 123ms/step - loss: 0.2894 - accuracy: 0.8963 - val_loss: 0.5211 - val_accuracy: 0.8360
# Epoch 29/300
# 79/79 [==============================] - 10s 123ms/step - loss: 0.2811 - accuracy: 0.9003 - val_loss: 0.5449 - val_accuracy: 0.8318
# Epoch 30/300
# 79/79 [==============================] - 10s 123ms/step - loss: 0.2590 - accuracy: 0.9075 - val_loss: 0.5462 - val_accuracy: 0.8326
# Epoch 31/300
# 79/79 [==============================] - 10s 123ms/step - loss: 0.2560 - accuracy: 0.9082 - val_loss: 0.6515 - val_accuracy: 0.8107
# Epoch 32/300
# 79/79 [==============================] - 10s 123ms/step - loss: 0.2408 - accuracy: 0.9142 - val_loss: 0.5363 - val_accuracy: 0.8377
# Epoch 33/300
# 79/79 [==============================] - 10s 124ms/step - loss: 0.2334 - accuracy: 0.9160 - val_loss: 0.5279 - val_accuracy: 0.8416
# Epoch 34/300
# 79/79 [==============================] - 10s 123ms/step - loss: 0.2226 - accuracy: 0.9201 - val_loss: 0.5334 - val_accuracy: 0.8452
# Epoch 35/300
# 79/79 [==============================] - 10s 124ms/step - loss: 0.2138 - accuracy: 0.9230 - val_loss: 0.5547 - val_accuracy: 0.8376
# Epoch 36/300
# 79/79 [==============================] - 10s 124ms/step - loss: 0.2050 - accuracy: 0.9259 - val_loss: 0.5602 - val_accuracy: 0.8431
# Epoch 37/300
# 79/79 [==============================] - 10s 124ms/step - loss: 0.2007 - accuracy: 0.9270 - val_loss: 0.5723 - val_accuracy: 0.8358
# Epoch 38/300
# 79/79 [==============================] - 10s 123ms/step - loss: 0.1884 - accuracy: 0.9325 - val_loss: 0.5882 - val_accuracy: 0.8380

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:06:13.242565

# %%
model.load_weights(checkpoint_filepath)

# %% [markdown]
# ## 6. Results Evaluation
#
# Let's obtain a graph of how the error and accuracy evolve at each epoch in the training and validation data.

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 83.390

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# The cost we can see that it is stable and it is at epoch 15 that it is fixed at a value. Also the accuracy dances around 0.10. We can't say that it is a very good model.
#
# Let's see what kind of predictions I'm getting on the test set (let's paint the images and their classifications)

# %%
predictions = model.predict(x_test)

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# We draw the first images, with the predictions and their real values (a total of 20 images, so as not to abuse your laptops).
#
# We color the correct predictions in blue and the failures in red. But first I have printed the labels so that we have a reference to the graph.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
