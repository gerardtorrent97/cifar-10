# %% [markdown]
# ## 1. Import Libraries

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 2. Neural Newtork Architecture

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.3))


model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(512, activation="relu"))
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(512, activation="relu"))
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(512, activation="relu"))
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               2097664
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 3,215,946
# Trainable params: 3,215,946
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Cost function

# %%
model.compile(optimizer="Adam",
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Data Preparation
#
# We load the CIFAR10 dataset directly from Keras. Those are already split in train and test.
#
#
# **Important:**
# > The neural network requires for the inputs to be real numbers. We can simply achieve this by divinding the values inside the matrices by 255.0.

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %%
# Let's plot a sample of the images

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# When we add convolutions, we need to preprocess the data, because **convolution is for an array of 4 fields** (more like "images"), not an array of 3 dimensions as the datasets for train, test and validation. So we need to **.reshape()**.
#
# That's why, when you exit the convolution, you have to flatten the matrices, because the FullDense layers expect arrays, not matrices!

# %%
# Let's validate the results
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# # 4. Early Stopping

# %%
callback_loss = EarlyStopping(monitor="val_loss", patience=15)
callback_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)

# %% [markdown]
# ## 5. Training
#
# Note that we have to train against the data converted to the format expected by the Convolution.
#
# We will start with 30 epochs, that is to say, 30 complete passes of the dataset (which in turn will be with mini-batches internally, setting the batches to 64 elements.
#
# The .fit() method allows us to define if we have several CPUs, GPUs, and if we want to validate data at each end of epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, 
                    epochs=128, 
                    use_multiprocessing=False, 
                    batch_size= 512, 
                    callbacks=[callback_accuracy, callback_loss],
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/128
# 79/79 [==============================] - 22s 217ms/step - loss: 2.2752 - accuracy: 0.1219 - val_loss: 1.9322 - val_accuracy: 0.2793
# Epoch 2/128
# 79/79 [==============================] - 15s 189ms/step - loss: 1.8694 - accuracy: 0.2887 - val_loss: 1.6037 - val_accuracy: 0.4014
# Epoch 3/128
# 79/79 [==============================] - 15s 189ms/step - loss: 1.5612 - accuracy: 0.4146 - val_loss: 1.5664 - val_accuracy: 0.4551
# Epoch 4/128
# 79/79 [==============================] - 15s 189ms/step - loss: 1.3505 - accuracy: 0.5052 - val_loss: 1.1199 - val_accuracy: 0.5907
# Epoch 5/128
# 79/79 [==============================] - 15s 190ms/step - loss: 1.1756 - accuracy: 0.5741 - val_loss: 1.0196 - val_accuracy: 0.6328
# Epoch 6/128
# 79/79 [==============================] - 15s 190ms/step - loss: 1.0455 - accuracy: 0.6288 - val_loss: 0.9322 - val_accuracy: 0.6599
# Epoch 7/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.9552 - accuracy: 0.6637 - val_loss: 0.9540 - val_accuracy: 0.6638
# Epoch 8/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.9090 - accuracy: 0.6826 - val_loss: 0.8817 - val_accuracy: 0.6934
# Epoch 9/128
# 79/79 [==============================] - 15s 189ms/step - loss: 0.8488 - accuracy: 0.7037 - val_loss: 0.7593 - val_accuracy: 0.7354
# Epoch 10/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.7542 - accuracy: 0.7385 - val_loss: 0.7399 - val_accuracy: 0.7403
# Epoch 11/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.7022 - accuracy: 0.7530 - val_loss: 0.7238 - val_accuracy: 0.7501
# Epoch 12/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.6593 - accuracy: 0.7706 - val_loss: 0.6890 - val_accuracy: 0.7652
# Epoch 13/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.6258 - accuracy: 0.7843 - val_loss: 0.6846 - val_accuracy: 0.7611
# Epoch 14/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.5854 - accuracy: 0.7979 - val_loss: 0.6900 - val_accuracy: 0.7651
# Epoch 15/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.5522 - accuracy: 0.8082 - val_loss: 0.6824 - val_accuracy: 0.7725
# Epoch 16/128
# 79/79 [==============================] - 15s 189ms/step - loss: 0.5379 - accuracy: 0.8128 - val_loss: 0.6538 - val_accuracy: 0.7773
# Epoch 17/128
# 79/79 [==============================] - 15s 189ms/step - loss: 0.5358 - accuracy: 0.8156 - val_loss: 0.5898 - val_accuracy: 0.7973
# Epoch 18/128
# 79/79 [==============================] - 15s 189ms/step - loss: 0.4658 - accuracy: 0.8347 - val_loss: 0.6204 - val_accuracy: 0.7904
# Epoch 19/128
# 79/79 [==============================] - 15s 189ms/step - loss: 0.4697 - accuracy: 0.8384 - val_loss: 0.8095 - val_accuracy: 0.7520
# Epoch 20/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.4802 - accuracy: 0.8338 - val_loss: 0.6359 - val_accuracy: 0.7916
# Epoch 21/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.4278 - accuracy: 0.8493 - val_loss: 0.6079 - val_accuracy: 0.8067
# Epoch 22/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.3805 - accuracy: 0.8688 - val_loss: 0.7237 - val_accuracy: 0.7788
# Epoch 23/128
# 79/79 [==============================] - 15s 189ms/step - loss: 0.4051 - accuracy: 0.8623 - val_loss: 0.6207 - val_accuracy: 0.8019
# Epoch 24/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.3621 - accuracy: 0.8746 - val_loss: 0.5786 - val_accuracy: 0.8143
# Epoch 25/128
# 79/79 [==============================] - 15s 189ms/step - loss: 0.3514 - accuracy: 0.8774 - val_loss: 0.6048 - val_accuracy: 0.8093
# Epoch 26/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.3524 - accuracy: 0.8760 - val_loss: 0.5993 - val_accuracy: 0.8127
# Epoch 27/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.3361 - accuracy: 0.8810 - val_loss: 0.5790 - val_accuracy: 0.8158
# Epoch 28/128
# 79/79 [==============================] - 15s 189ms/step - loss: 0.3161 - accuracy: 0.8903 - val_loss: 0.5923 - val_accuracy: 0.8169
# Epoch 29/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.2953 - accuracy: 0.8957 - val_loss: 0.6000 - val_accuracy: 0.8208
# Epoch 30/128
# 79/79 [==============================] - 15s 189ms/step - loss: 0.2765 - accuracy: 0.9017 - val_loss: 0.5702 - val_accuracy: 0.8273
# Epoch 31/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.2582 - accuracy: 0.9087 - val_loss: 0.5873 - val_accuracy: 0.8281
# Epoch 32/128
# 79/79 [==============================] - 15s 189ms/step - loss: 0.2550 - accuracy: 0.9113 - val_loss: 0.6156 - val_accuracy: 0.8158
# Epoch 33/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.2719 - accuracy: 0.9065 - val_loss: 0.6066 - val_accuracy: 0.8194
# Epoch 34/128
# 79/79 [==============================] - 15s 189ms/step - loss: 0.2704 - accuracy: 0.9060 - val_loss: 0.6128 - val_accuracy: 0.8202
# Epoch 35/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.2493 - accuracy: 0.9115 - val_loss: 0.6185 - val_accuracy: 0.8238
# Epoch 36/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.2343 - accuracy: 0.9189 - val_loss: 0.6078 - val_accuracy: 0.8311
# Epoch 37/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.2251 - accuracy: 0.9219 - val_loss: 0.6041 - val_accuracy: 0.8209
# Epoch 38/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.2158 - accuracy: 0.9258 - val_loss: 0.5889 - val_accuracy: 0.8274
# Epoch 39/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.2208 - accuracy: 0.9243 - val_loss: 0.6171 - val_accuracy: 0.8259
# Epoch 40/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.2211 - accuracy: 0.9214 - val_loss: 0.6224 - val_accuracy: 0.8258
# Epoch 41/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.1911 - accuracy: 0.9340 - val_loss: 0.6351 - val_accuracy: 0.8293
# Epoch 42/128
# 79/79 [==============================] - 15s 189ms/step - loss: 0.2048 - accuracy: 0.9280 - val_loss: 0.6682 - val_accuracy: 0.8236
# Epoch 43/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.1996 - accuracy: 0.9314 - val_loss: 0.6352 - val_accuracy: 0.8279
# Epoch 44/128
# 79/79 [==============================] - 15s 189ms/step - loss: 0.1967 - accuracy: 0.9311 - val_loss: 0.6347 - val_accuracy: 0.8225
# Epoch 45/128
# 79/79 [==============================] - 15s 190ms/step - loss: 0.1867 - accuracy: 0.9367 - val_loss: 0.7175 - val_accuracy: 0.8211

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:11:21.914286

# %% [markdown]
# ## 6. Results Evaluation
#
# Let's obtain a graph of how the error and accuracy evolve at each epoch in the training and validation data.

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 81.300

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# The cost we can see that it is stable and it is at epoch 15 that it is fixed at a value. Also the accuracy dances around 0.10. We can't say that it is a very good model.
#
# Let's see what kind of predictions I'm getting on the test set (let's paint the images and their classifications)

# %%
predictions = model.predict(x_test)

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# We draw the first images, with the predictions and their real values (a total of 20 images, so as not to abuse your laptops).
#
# We color the correct predictions in blue and the failures in red. But first I have printed the labels so that we have a reference to the graph.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
