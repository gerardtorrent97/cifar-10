# %% [markdown]
# ## 1. Import Libraries

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 2. Neural Newtork Architecture

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.35))

model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))


model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(64, activation="relu"))
model.add(ks.layers.Dense(64, activation="relu"))
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 128)       3584
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        73792
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 256)       147712
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 128)       295040
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 64)          73792
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                65600
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 1,475,850
# Trainable params: 1,475,850
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Cost function

# %%
adam = Adam(learning_rate=3e-4)

# %%
model.compile(optimizer=adam,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Data Preparation
#
# We load the CIFAR10 dataset directly from Keras. Those are already split in train and test.
#
#
# **Important:**
# > The neural network requires for the inputs to be real numbers. We can simply achieve this by divinding the values inside the matrices by 255.0.

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %%
# Let's plot a sample of the images

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# When we add convolutions, we need to preprocess the data, because **convolution is for an array of 4 fields** (more like "images"), not an array of 3 dimensions as the datasets for train, test and validation. So we need to **.reshape()**.
#
# That's why, when you exit the convolution, you have to flatten the matrices, because the FullDense layers expect arrays, not matrices!

# %%
# Let's validate the results
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# # 4. Early Stopping

# %%
callback_loss = EarlyStopping(monitor="val_loss", patience=15)
callback_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)

# %% [markdown]
# ## 5. Training
#
# Note that we have to train against the data converted to the format expected by the Convolution.
#
# We will start with 30 epochs, that is to say, 30 complete passes of the dataset (which in turn will be with mini-batches internally, setting the batches to 64 elements.
#
# The .fit() method allows us to define if we have several CPUs, GPUs, and if we want to validate data at each end of epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, 
                    epochs=300, 
                    use_multiprocessing=False, 
                    batch_size= 512, 
                    callbacks=[callback_accuracy, callback_loss],
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/300
# 79/79 [==============================] - 29s 242ms/step - loss: 2.2992 - accuracy: 0.1093 - val_loss: 2.3023 - val_accuracy: 0.0980
# Epoch 2/300
# 79/79 [==============================] - 16s 197ms/step - loss: 2.2723 - accuracy: 0.1361 - val_loss: 2.1127 - val_accuracy: 0.2312
# Epoch 3/300
# 79/79 [==============================] - 15s 196ms/step - loss: 1.9831 - accuracy: 0.2588 - val_loss: 1.6775 - val_accuracy: 0.3728
# Epoch 4/300
# 79/79 [==============================] - 15s 194ms/step - loss: 1.7144 - accuracy: 0.3567 - val_loss: 1.5111 - val_accuracy: 0.4300
# Epoch 5/300
# 79/79 [==============================] - 15s 194ms/step - loss: 1.5853 - accuracy: 0.4084 - val_loss: 1.4096 - val_accuracy: 0.4786
# Epoch 6/300
# 79/79 [==============================] - 15s 195ms/step - loss: 1.4498 - accuracy: 0.4634 - val_loss: 1.2710 - val_accuracy: 0.5321
# Epoch 7/300
# 79/79 [==============================] - 15s 195ms/step - loss: 1.3667 - accuracy: 0.4994 - val_loss: 1.5942 - val_accuracy: 0.4421
# Epoch 8/300
# 79/79 [==============================] - 15s 196ms/step - loss: 1.3626 - accuracy: 0.5083 - val_loss: 1.1235 - val_accuracy: 0.5902
# Epoch 9/300
# 79/79 [==============================] - 15s 196ms/step - loss: 1.1897 - accuracy: 0.5772 - val_loss: 1.0902 - val_accuracy: 0.6029
# Epoch 10/300
# 79/79 [==============================] - 15s 196ms/step - loss: 1.1302 - accuracy: 0.5962 - val_loss: 1.0710 - val_accuracy: 0.6153
# Epoch 11/300
# 79/79 [==============================] - 15s 196ms/step - loss: 1.0663 - accuracy: 0.6178 - val_loss: 0.9344 - val_accuracy: 0.6617
# Epoch 12/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.9942 - accuracy: 0.6494 - val_loss: 0.9253 - val_accuracy: 0.6702
# Epoch 13/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.9522 - accuracy: 0.6695 - val_loss: 0.8736 - val_accuracy: 0.6867
# Epoch 14/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.9008 - accuracy: 0.6848 - val_loss: 0.8486 - val_accuracy: 0.7003
# Epoch 15/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.8762 - accuracy: 0.6976 - val_loss: 0.8356 - val_accuracy: 0.7081
# Epoch 16/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.8231 - accuracy: 0.7132 - val_loss: 0.7715 - val_accuracy: 0.7256
# Epoch 17/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.8033 - accuracy: 0.7199 - val_loss: 0.7364 - val_accuracy: 0.7402
# Epoch 18/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.7627 - accuracy: 0.7356 - val_loss: 0.7072 - val_accuracy: 0.7527
# Epoch 19/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.7247 - accuracy: 0.7491 - val_loss: 0.7111 - val_accuracy: 0.7494
# Epoch 20/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.7116 - accuracy: 0.7540 - val_loss: 0.6899 - val_accuracy: 0.7584
# Epoch 21/300
# 79/79 [==============================] - 16s 196ms/step - loss: 0.6784 - accuracy: 0.7662 - val_loss: 0.6545 - val_accuracy: 0.7746
# Epoch 22/300
# 79/79 [==============================] - 16s 197ms/step - loss: 0.6379 - accuracy: 0.7838 - val_loss: 0.6326 - val_accuracy: 0.7824
# Epoch 23/300
# 79/79 [==============================] - 16s 197ms/step - loss: 0.6431 - accuracy: 0.7800 - val_loss: 0.6860 - val_accuracy: 0.7658
# Epoch 24/300
# 79/79 [==============================] - 16s 196ms/step - loss: 0.5991 - accuracy: 0.7940 - val_loss: 0.6150 - val_accuracy: 0.7863
# Epoch 25/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.5859 - accuracy: 0.7988 - val_loss: 0.5874 - val_accuracy: 0.7966
# Epoch 26/300
# 79/79 [==============================] - 16s 196ms/step - loss: 0.5792 - accuracy: 0.8026 - val_loss: 0.6032 - val_accuracy: 0.7924
# Epoch 27/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.5435 - accuracy: 0.8150 - val_loss: 0.5816 - val_accuracy: 0.8010
# Epoch 28/300
# 79/79 [==============================] - 16s 197ms/step - loss: 0.5364 - accuracy: 0.8178 - val_loss: 0.5724 - val_accuracy: 0.8034
# Epoch 29/300
# 79/79 [==============================] - 16s 197ms/step - loss: 0.5147 - accuracy: 0.8243 - val_loss: 0.6127 - val_accuracy: 0.7980
# Epoch 30/300
# 79/79 [==============================] - 16s 197ms/step - loss: 0.5084 - accuracy: 0.8255 - val_loss: 0.5950 - val_accuracy: 0.8002
# Epoch 31/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.4787 - accuracy: 0.8360 - val_loss: 0.5892 - val_accuracy: 0.8037
# Epoch 32/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.4873 - accuracy: 0.8330 - val_loss: 0.5780 - val_accuracy: 0.8105
# Epoch 33/300
# 79/79 [==============================] - 16s 197ms/step - loss: 0.4793 - accuracy: 0.8398 - val_loss: 0.6006 - val_accuracy: 0.8040
# Epoch 34/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.4440 - accuracy: 0.8464 - val_loss: 0.5807 - val_accuracy: 0.8055
# Epoch 35/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.4391 - accuracy: 0.8490 - val_loss: 0.5378 - val_accuracy: 0.8213
# Epoch 36/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.4157 - accuracy: 0.8594 - val_loss: 0.5781 - val_accuracy: 0.8100
# Epoch 37/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.4111 - accuracy: 0.8600 - val_loss: 0.5614 - val_accuracy: 0.8171
# Epoch 38/300
# 79/79 [==============================] - 16s 197ms/step - loss: 0.3992 - accuracy: 0.8629 - val_loss: 0.5804 - val_accuracy: 0.8079
# Epoch 39/300
# 79/79 [==============================] - 16s 197ms/step - loss: 0.3997 - accuracy: 0.8640 - val_loss: 0.5726 - val_accuracy: 0.8144
# Epoch 40/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.3862 - accuracy: 0.8687 - val_loss: 0.5733 - val_accuracy: 0.8153
# Epoch 41/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.3988 - accuracy: 0.8629 - val_loss: 0.5499 - val_accuracy: 0.8224
# Epoch 42/300
# 79/79 [==============================] - 16s 196ms/step - loss: 0.3921 - accuracy: 0.8670 - val_loss: 0.5619 - val_accuracy: 0.8264
# Epoch 43/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.3620 - accuracy: 0.8760 - val_loss: 0.5925 - val_accuracy: 0.8170
# Epoch 44/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.3739 - accuracy: 0.8702 - val_loss: 0.5446 - val_accuracy: 0.8260
# Epoch 45/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.3446 - accuracy: 0.8806 - val_loss: 0.5309 - val_accuracy: 0.8323
# Epoch 46/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.3291 - accuracy: 0.8866 - val_loss: 0.5348 - val_accuracy: 0.8326
# Epoch 47/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.3499 - accuracy: 0.8799 - val_loss: 0.5634 - val_accuracy: 0.8284
# Epoch 48/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.3242 - accuracy: 0.8882 - val_loss: 0.5571 - val_accuracy: 0.8318
# Epoch 49/300
# 79/79 [==============================] - 16s 197ms/step - loss: 0.3246 - accuracy: 0.8883 - val_loss: 0.5478 - val_accuracy: 0.8346
# Epoch 50/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.3016 - accuracy: 0.8969 - val_loss: 0.5924 - val_accuracy: 0.8226
# Epoch 51/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.3139 - accuracy: 0.8937 - val_loss: 0.6733 - val_accuracy: 0.8053
# Epoch 52/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.3409 - accuracy: 0.8847 - val_loss: 0.5526 - val_accuracy: 0.8284
# Epoch 53/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.3113 - accuracy: 0.8918 - val_loss: 0.5801 - val_accuracy: 0.8296
# Epoch 54/300
# 79/79 [==============================] - 16s 196ms/step - loss: 0.3040 - accuracy: 0.8965 - val_loss: 0.5895 - val_accuracy: 0.8238
# Epoch 55/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.2922 - accuracy: 0.8998 - val_loss: 0.5516 - val_accuracy: 0.8354
# Epoch 56/300
# 79/79 [==============================] - 16s 197ms/step - loss: 0.2856 - accuracy: 0.9000 - val_loss: 0.5517 - val_accuracy: 0.8367
# Epoch 57/300
# 79/79 [==============================] - 16s 197ms/step - loss: 0.2576 - accuracy: 0.9117 - val_loss: 0.5514 - val_accuracy: 0.8323
# Epoch 58/300
# 79/79 [==============================] - 16s 197ms/step - loss: 0.2763 - accuracy: 0.9067 - val_loss: 0.5473 - val_accuracy: 0.8338
# Epoch 59/300
# 79/79 [==============================] - 16s 196ms/step - loss: 0.2579 - accuracy: 0.9106 - val_loss: 0.5523 - val_accuracy: 0.8391
# Epoch 60/300
# 79/79 [==============================] - 15s 196ms/step - loss: 0.2706 - accuracy: 0.9094 - val_loss: 0.5566 - val_accuracy: 0.8377

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:15:43.212253

# %% [markdown]
# ## 6. Results Evaluation
#
# Let's obtain a graph of how the error and accuracy evolve at each epoch in the training and validation data.

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 83.720

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# The cost we can see that it is stable and it is at epoch 15 that it is fixed at a value. Also the accuracy dances around 0.10. We can't say that it is a very good model.
#
# Let's see what kind of predictions I'm getting on the test set (let's paint the images and their classifications)

# %%
predictions = model.predict(x_test)

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# We draw the first images, with the predictions and their real values (a total of 20 images, so as not to abuse your laptops).
#
# We color the correct predictions in blue and the failures in red. But first I have printed the labels so that we have a reference to the graph.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
