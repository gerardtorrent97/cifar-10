# %% [markdown]
# ## 1. Import Libraries

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## 2. Neural Newtork Architecture

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(512, activation="relu"))
model.add(ks.layers.Dense(512, activation="relu"))
model.add(ks.layers.Dense(512, activation="relu"))
model.add(ks.layers.Dense(512, activation="relu"))
model.add(ks.layers.Dense(512, activation="relu"))
model.add(ks.layers.Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 256)       147712
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 64)          147520
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         147712
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               2097664
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 4,852,170
# Trainable params: 4,852,170
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Cost function

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Data Preparation
#
# We load the CIFAR10 dataset directly from Keras. Those are already split in train and test.
#
#
# **Important:**
# > The neural network requires for the inputs to be real numbers. We can simply achieve this by divinding the values inside the matrices by 255.0.

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %%
# Let's plot a sample of the images

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# When we add convolutions, we need to preprocess the data, because **convolution is for an array of 4 fields** (more like "images"), not an array of 3 dimensions as the datasets for train, test and validation. So we need to **.reshape()**.
#
# That's why, when you exit the convolution, you have to flatten the matrices, because the FullDense layers expect arrays, not matrices!

# %%
# Let's validate the results
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# # 4. Early Stopping

# %%
callback_loss = EarlyStopping(monitor="val_loss", patience=15)
callback_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)

# %% [markdown]
# ## 5. Training
#
# Note that we have to train against the data converted to the format expected by the Convolution.
#
# We will start with 30 epochs, that is to say, 30 complete passes of the dataset (which in turn will be with mini-batches internally, setting the batches to 64 elements.
#
# The .fit() method allows us to define if we have several CPUs, GPUs, and if we want to validate data at each end of epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, 
                    epochs=128, 
                    use_multiprocessing=False, 
                    batch_size= 512, 
                    callbacks=[callback_accuracy, callback_loss],
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/128
# 79/79 [==============================] - 22s 182ms/step - loss: 2.2996 - accuracy: 0.1022 - val_loss: 2.0615 - val_accuracy: 0.1853
# Epoch 2/128
# 79/79 [==============================] - 12s 148ms/step - loss: 2.0005 - accuracy: 0.2153 - val_loss: 1.8098 - val_accuracy: 0.2788
# Epoch 3/128
# 79/79 [==============================] - 12s 151ms/step - loss: 1.7743 - accuracy: 0.3064 - val_loss: 1.7170 - val_accuracy: 0.3501
# Epoch 4/128
# 79/79 [==============================] - 12s 152ms/step - loss: 1.6035 - accuracy: 0.3830 - val_loss: 1.4678 - val_accuracy: 0.4338
# Epoch 5/128
# 79/79 [==============================] - 12s 151ms/step - loss: 1.4015 - accuracy: 0.4708 - val_loss: 1.3616 - val_accuracy: 0.4993
# Epoch 6/128
# 79/79 [==============================] - 12s 151ms/step - loss: 1.2419 - accuracy: 0.5410 - val_loss: 1.1419 - val_accuracy: 0.5828
# Epoch 7/128
# 79/79 [==============================] - 12s 150ms/step - loss: 1.1244 - accuracy: 0.5888 - val_loss: 1.1074 - val_accuracy: 0.6138
# Epoch 8/128
# 79/79 [==============================] - 12s 150ms/step - loss: 1.0285 - accuracy: 0.6302 - val_loss: 0.9735 - val_accuracy: 0.6502
# Epoch 9/128
# 79/79 [==============================] - 12s 150ms/step - loss: 0.9181 - accuracy: 0.6684 - val_loss: 0.9066 - val_accuracy: 0.6747
# Epoch 10/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.8572 - accuracy: 0.6897 - val_loss: 0.8577 - val_accuracy: 0.7040
# Epoch 11/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.7902 - accuracy: 0.7181 - val_loss: 0.9419 - val_accuracy: 0.6678
# Epoch 12/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.7582 - accuracy: 0.7324 - val_loss: 0.7801 - val_accuracy: 0.7248
# Epoch 13/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.6800 - accuracy: 0.7606 - val_loss: 0.7536 - val_accuracy: 0.7408
# Epoch 14/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.6427 - accuracy: 0.7730 - val_loss: 0.7364 - val_accuracy: 0.7457
# Epoch 15/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.5988 - accuracy: 0.7882 - val_loss: 0.7376 - val_accuracy: 0.7555
# Epoch 16/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.5710 - accuracy: 0.8010 - val_loss: 0.6988 - val_accuracy: 0.7604
# Epoch 17/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.5448 - accuracy: 0.8084 - val_loss: 0.6898 - val_accuracy: 0.7691
# Epoch 18/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.5244 - accuracy: 0.8152 - val_loss: 0.8412 - val_accuracy: 0.7411
# Epoch 19/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.4835 - accuracy: 0.8312 - val_loss: 0.7796 - val_accuracy: 0.7457
# Epoch 20/128
# 79/79 [==============================] - 12s 152ms/step - loss: 0.4775 - accuracy: 0.8326 - val_loss: 0.7993 - val_accuracy: 0.7499
# Epoch 21/128
# 79/79 [==============================] - 12s 152ms/step - loss: 0.4406 - accuracy: 0.8456 - val_loss: 0.6742 - val_accuracy: 0.7857
# Epoch 22/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.4071 - accuracy: 0.8576 - val_loss: 0.7198 - val_accuracy: 0.7688
# Epoch 23/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.4315 - accuracy: 0.8475 - val_loss: 0.6318 - val_accuracy: 0.7972
# Epoch 24/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.3841 - accuracy: 0.8664 - val_loss: 0.7120 - val_accuracy: 0.7803
# Epoch 25/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.3492 - accuracy: 0.8768 - val_loss: 0.6783 - val_accuracy: 0.7914
# Epoch 26/128
# 79/79 [==============================] - 12s 152ms/step - loss: 0.3367 - accuracy: 0.8794 - val_loss: 0.6852 - val_accuracy: 0.7883
# Epoch 27/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.3326 - accuracy: 0.8815 - val_loss: 0.6748 - val_accuracy: 0.8030
# Epoch 28/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.3081 - accuracy: 0.8894 - val_loss: 0.7457 - val_accuracy: 0.7882
# Epoch 29/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.3061 - accuracy: 0.8930 - val_loss: 0.6632 - val_accuracy: 0.8071
# Epoch 30/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.2753 - accuracy: 0.9025 - val_loss: 0.7353 - val_accuracy: 0.8007
# Epoch 31/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.2761 - accuracy: 0.9027 - val_loss: 0.6998 - val_accuracy: 0.8056
# Epoch 32/128
# 79/79 [==============================] - 12s 152ms/step - loss: 0.2681 - accuracy: 0.9055 - val_loss: 0.6892 - val_accuracy: 0.8147
# Epoch 33/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.2560 - accuracy: 0.9095 - val_loss: 0.6966 - val_accuracy: 0.8042
# Epoch 34/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.2318 - accuracy: 0.9175 - val_loss: 0.7094 - val_accuracy: 0.8077
# Epoch 35/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.2337 - accuracy: 0.9167 - val_loss: 0.7995 - val_accuracy: 0.7890
# Epoch 36/128
# 79/79 [==============================] - 12s 151ms/step - loss: 0.2512 - accuracy: 0.9107 - val_loss: 0.7142 - val_accuracy: 0.8051
# Epoch 37/128
# 79/79 [==============================] - 12s 152ms/step - loss: 0.2131 - accuracy: 0.9257 - val_loss: 0.6974 - val_accuracy: 0.8080
# Epoch 38/128
# 79/79 [==============================] - 12s 152ms/step - loss: 0.2057 - accuracy: 0.9265 - val_loss: 0.7865 - val_accuracy: 0.8029

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:07:44.788121

# %% [markdown]
# ## 6. Results Evaluation
#
# Let's obtain a graph of how the error and accuracy evolve at each epoch in the training and validation data.

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 79.740

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# The cost we can see that it is stable and it is at epoch 15 that it is fixed at a value. Also the accuracy dances around 0.10. We can't say that it is a very good model.
#
# Let's see what kind of predictions I'm getting on the test set (let's paint the images and their classifications)

# %%
predictions = model.predict(x_test)

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# We draw the first images, with the predictions and their real values (a total of 20 images, so as not to abuse your laptops).
#
# We color the correct predictions in blue and the failures in red. But first I have printed the labels so that we have a reference to the graph.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
