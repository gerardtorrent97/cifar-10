# %% [markdown]
# ## 1. Import Libraries

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 2. Neural Newtork Architecture

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Conv2D(
    filters=32, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.3))


model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(256, activation="relu"))
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(256, activation="relu"))
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 32)          73760
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         36992
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1048832
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 2,631,594
# Trainable params: 2,631,594
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Cost function

# %%
adam = Adam(learning_rate=3e-2)

# %%
model.compile(optimizer="Adam",
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Data Preparation
#
# We load the CIFAR10 dataset directly from Keras. Those are already split in train and test.
#
#
# **Important:**
# > The neural network requires for the inputs to be real numbers. We can simply achieve this by divinding the values inside the matrices by 255.0.

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %%
# Let's plot a sample of the images

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# When we add convolutions, we need to preprocess the data, because **convolution is for an array of 4 fields** (more like "images"), not an array of 3 dimensions as the datasets for train, test and validation. So we need to **.reshape()**.
#
# That's why, when you exit the convolution, you have to flatten the matrices, because the FullDense layers expect arrays, not matrices!

# %%
# Let's validate the results
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# # 4. Early Stopping

# %%
callback_loss = EarlyStopping(monitor="val_loss", patience=15)
callback_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)

# %% [markdown]
# ## 5. Training
#
# Note that we have to train against the data converted to the format expected by the Convolution.
#
# We will start with 30 epochs, that is to say, 30 complete passes of the dataset (which in turn will be with mini-batches internally, setting the batches to 64 elements.
#
# The .fit() method allows us to define if we have several CPUs, GPUs, and if we want to validate data at each end of epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, 
                    epochs=128, 
                    use_multiprocessing=False, 
                    batch_size= 512, 
                    callbacks=[callback_accuracy, callback_loss],
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/128
# 79/79 [==============================] - 44s 424ms/step - loss: 2.2788 - accuracy: 0.1205 - val_loss: 1.9551 - val_accuracy: 0.2765
# Epoch 2/128
# 79/79 [==============================] - 29s 364ms/step - loss: 1.8939 - accuracy: 0.2963 - val_loss: 1.5947 - val_accuracy: 0.4033
# Epoch 3/128
# 79/79 [==============================] - 29s 363ms/step - loss: 1.5999 - accuracy: 0.4017 - val_loss: 1.4468 - val_accuracy: 0.4706
# Epoch 4/128
# 79/79 [==============================] - 29s 363ms/step - loss: 1.3726 - accuracy: 0.5032 - val_loss: 1.2335 - val_accuracy: 0.5591
# Epoch 5/128
# 79/79 [==============================] - 29s 364ms/step - loss: 1.2267 - accuracy: 0.5599 - val_loss: 1.1956 - val_accuracy: 0.5842
# Epoch 6/128
# 79/79 [==============================] - 29s 364ms/step - loss: 1.1212 - accuracy: 0.5955 - val_loss: 1.0068 - val_accuracy: 0.6445
# Epoch 7/128
# 79/79 [==============================] - 29s 363ms/step - loss: 0.9981 - accuracy: 0.6442 - val_loss: 0.9787 - val_accuracy: 0.6533
# Epoch 8/128
# 79/79 [==============================] - 29s 363ms/step - loss: 0.9500 - accuracy: 0.6638 - val_loss: 0.8876 - val_accuracy: 0.6931
# Epoch 9/128
# 79/79 [==============================] - 29s 365ms/step - loss: 0.8851 - accuracy: 0.6911 - val_loss: 0.8430 - val_accuracy: 0.7085
# Epoch 10/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.8126 - accuracy: 0.7154 - val_loss: 0.7984 - val_accuracy: 0.7274
# Epoch 11/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.7573 - accuracy: 0.7354 - val_loss: 0.7931 - val_accuracy: 0.7249
# Epoch 12/128
# 79/79 [==============================] - 29s 363ms/step - loss: 0.7206 - accuracy: 0.7460 - val_loss: 0.7761 - val_accuracy: 0.7273
# Epoch 13/128
# 79/79 [==============================] - 29s 365ms/step - loss: 0.6941 - accuracy: 0.7562 - val_loss: 0.6915 - val_accuracy: 0.7609
# Epoch 14/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.6297 - accuracy: 0.7803 - val_loss: 0.7430 - val_accuracy: 0.7525
# Epoch 15/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.6203 - accuracy: 0.7824 - val_loss: 0.6950 - val_accuracy: 0.7668
# Epoch 16/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.5443 - accuracy: 0.8103 - val_loss: 0.6580 - val_accuracy: 0.7788
# Epoch 17/128
# 79/79 [==============================] - 29s 365ms/step - loss: 0.5508 - accuracy: 0.8080 - val_loss: 0.7983 - val_accuracy: 0.7502
# Epoch 18/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.5416 - accuracy: 0.8113 - val_loss: 0.6438 - val_accuracy: 0.7854
# Epoch 19/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.4763 - accuracy: 0.8344 - val_loss: 0.6388 - val_accuracy: 0.7870
# Epoch 20/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.4543 - accuracy: 0.8401 - val_loss: 0.6497 - val_accuracy: 0.7827
# Epoch 21/128
# 79/79 [==============================] - 29s 365ms/step - loss: 0.4535 - accuracy: 0.8407 - val_loss: 0.6278 - val_accuracy: 0.7959
# Epoch 22/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.4101 - accuracy: 0.8562 - val_loss: 0.6416 - val_accuracy: 0.7952
# Epoch 23/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.4024 - accuracy: 0.8554 - val_loss: 0.6521 - val_accuracy: 0.7908
# Epoch 24/128
# 79/79 [==============================] - 29s 363ms/step - loss: 0.3881 - accuracy: 0.8628 - val_loss: 0.7097 - val_accuracy: 0.7833
# Epoch 25/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.3743 - accuracy: 0.8689 - val_loss: 0.6354 - val_accuracy: 0.8014
# Epoch 26/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.3512 - accuracy: 0.8762 - val_loss: 0.6252 - val_accuracy: 0.7981
# Epoch 27/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.3326 - accuracy: 0.8832 - val_loss: 0.6576 - val_accuracy: 0.8007
# Epoch 28/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.3219 - accuracy: 0.8864 - val_loss: 0.7381 - val_accuracy: 0.7813
# Epoch 29/128
# 79/79 [==============================] - 29s 365ms/step - loss: 0.3260 - accuracy: 0.8852 - val_loss: 0.7398 - val_accuracy: 0.7924
# Epoch 30/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.3205 - accuracy: 0.8897 - val_loss: 0.6716 - val_accuracy: 0.8000
# Epoch 31/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.3040 - accuracy: 0.8940 - val_loss: 0.6741 - val_accuracy: 0.8011
# Epoch 32/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.2629 - accuracy: 0.9067 - val_loss: 0.7099 - val_accuracy: 0.7930
# Epoch 33/128
# 79/79 [==============================] - 29s 365ms/step - loss: 0.2736 - accuracy: 0.9045 - val_loss: 0.6964 - val_accuracy: 0.8055
# Epoch 34/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.2529 - accuracy: 0.9109 - val_loss: 0.6723 - val_accuracy: 0.8041
# Epoch 35/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.2615 - accuracy: 0.9090 - val_loss: 0.6653 - val_accuracy: 0.8080
# Epoch 36/128
# 79/79 [==============================] - 29s 363ms/step - loss: 0.2405 - accuracy: 0.9161 - val_loss: 0.6498 - val_accuracy: 0.8120
# Epoch 37/128
# 79/79 [==============================] - 29s 365ms/step - loss: 0.2371 - accuracy: 0.9166 - val_loss: 0.7150 - val_accuracy: 0.8009
# Epoch 38/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.2332 - accuracy: 0.9174 - val_loss: 0.6960 - val_accuracy: 0.8023
# Epoch 39/128
# 79/79 [==============================] - 29s 364ms/step - loss: 0.2412 - accuracy: 0.9165 - val_loss: 0.7283 - val_accuracy: 0.7988
# Epoch 40/128
# 79/79 [==============================] - 29s 363ms/step - loss: 0.2222 - accuracy: 0.9210 - val_loss: 0.7052 - val_accuracy: 0.8108
# Epoch 41/128
# 79/79 [==============================] - 29s 365ms/step - loss: 0.2038 - accuracy: 0.9279 - val_loss: 0.7132 - val_accuracy: 0.8074

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:19:54.120237

# %% [markdown]
# ## 6. Results Evaluation
#
# Let's obtain a graph of how the error and accuracy evolve at each epoch in the training and validation data.

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 80.250

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# The cost we can see that it is stable and it is at epoch 15 that it is fixed at a value. Also the accuracy dances around 0.10. We can't say that it is a very good model.
#
# Let's see what kind of predictions I'm getting on the test set (let's paint the images and their classifications)

# %%
predictions = model.predict(x_test)

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# We draw the first images, with the predictions and their real values (a total of 20 images, so as not to abuse your laptops).
#
# We color the correct predictions in blue and the failures in red. But first I have printed the labels so that we have a reference to the graph.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
