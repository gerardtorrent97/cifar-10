# %% [markdown]
# ## 1. Import Libraries

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 2. Neural Newtork Architecture

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.35))

model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))


model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(64, activation="relu"))
model.add(ks.layers.Dense(64, activation="relu"))
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 64)          147520
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                131136
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 1,097,162
# Trainable params: 1,097,162
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Cost function

# %%
adam = Adam(learning_rate=3e-4)

# %%
model.compile(optimizer=adam,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Data Preparation
#
# We load the CIFAR10 dataset directly from Keras. Those are already split in train and test.
#
#
# **Important:**
# > The neural network requires for the inputs to be real numbers. We can simply achieve this by divinding the values inside the matrices by 255.0.

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %%
# Let's plot a sample of the images

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# When we add convolutions, we need to preprocess the data, because **convolution is for an array of 4 fields** (more like "images"), not an array of 3 dimensions as the datasets for train, test and validation. So we need to **.reshape()**.
#
# That's why, when you exit the convolution, you have to flatten the matrices, because the FullDense layers expect arrays, not matrices!

# %%
# Let's validate the results
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# # 4. Early Stopping

# %%
callback_loss = EarlyStopping(monitor="val_loss", patience=15)
callback_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)

# %% [markdown]
# ## 5. Training
#
# Note that we have to train against the data converted to the format expected by the Convolution.
#
# We will start with 30 epochs, that is to say, 30 complete passes of the dataset (which in turn will be with mini-batches internally, setting the batches to 64 elements.
#
# The .fit() method allows us to define if we have several CPUs, GPUs, and if we want to validate data at each end of epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, 
                    epochs=300, 
                    use_multiprocessing=False, 
                    batch_size= 512, 
                    callbacks=[callback_accuracy, callback_loss],
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/300
# 79/79 [==============================] - 52s 191ms/step - loss: 2.2518 - accuracy: 0.1314 - val_loss: 1.9571 - val_accuracy: 0.2562
# Epoch 2/300
# 79/79 [==============================] - 13s 161ms/step - loss: 1.9520 - accuracy: 0.2593 - val_loss: 1.7983 - val_accuracy: 0.3247
# Epoch 3/300
# 79/79 [==============================] - 13s 163ms/step - loss: 1.7965 - accuracy: 0.3220 - val_loss: 1.6391 - val_accuracy: 0.3967
# Epoch 4/300
# 79/79 [==============================] - 13s 164ms/step - loss: 1.6287 - accuracy: 0.3937 - val_loss: 1.4455 - val_accuracy: 0.4709
# Epoch 5/300
# 79/79 [==============================] - 13s 164ms/step - loss: 1.5227 - accuracy: 0.4382 - val_loss: 1.4214 - val_accuracy: 0.4854
# Epoch 6/300
# 79/79 [==============================] - 13s 165ms/step - loss: 1.4081 - accuracy: 0.4844 - val_loss: 1.2814 - val_accuracy: 0.5382
# Epoch 7/300
# 79/79 [==============================] - 13s 166ms/step - loss: 1.3376 - accuracy: 0.5170 - val_loss: 1.2015 - val_accuracy: 0.5659
# Epoch 8/300
# 79/79 [==============================] - 13s 167ms/step - loss: 1.2564 - accuracy: 0.5488 - val_loss: 1.1584 - val_accuracy: 0.5813
# Epoch 9/300
# 79/79 [==============================] - 13s 168ms/step - loss: 1.2025 - accuracy: 0.5678 - val_loss: 1.0788 - val_accuracy: 0.6151
# Epoch 10/300
# 79/79 [==============================] - 13s 169ms/step - loss: 1.1498 - accuracy: 0.5884 - val_loss: 1.0229 - val_accuracy: 0.6313
# Epoch 11/300
300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.5526 - accuracy: 0.8098 - val_loss: 0.5975 - val_accuracy: 0.7968
# Epoch 36/300
# 79/79 [==============================] - 13s 171ms/step - loss: 0.5529 - accuracy: 0.8102 - val_loss: 0.6141 - val_accuracy: 0.7893
# Epoch 37/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.5379 - accuracy: 0.8142 - val_loss: 0.5777 - val_accuracy: 0.7983
# Epoch 38/300
# 79/79 [==============================] - 13s 171ms/step - loss: 0.5267 - accuracy: 0.8203 - val_loss: 0.6086 - val_accuracy: 0.7909
# Epoch 39/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.5153 - accuracy: 0.8268 - val_loss: 0.6123 - val_accuracy: 0.7923
# Epoch 40/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.5229 - accuracy: 0.8192 - val_loss: 0.6402 - val_accuracy: 0.7868
# Epoch 41/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.5210 - accuracy: 0.8200 - val_loss: 0.5862 - val_accuracy: 0.8015
# Epoch 42/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.5050 - accuracy: 0.8258 - val_loss: 0.5569 - val_accuracy: 0.8128
# Epoch 43/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.4735 - accuracy: 0.8385 - val_loss: 0.5474 - val_accuracy: 0.8172
# Epoch 44/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.4698 - accuracy: 0.8388 - val_loss: 0.5466 - val_accuracy: 0.8166
# Epoch 45/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.4813 - accuracy: 0.8332 - val_loss: 0.5544 - val_accuracy: 0.8095
# Epoch 46/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.4558 - accuracy: 0.8460 - val_loss: 0.5330 - val_accuracy: 0.8209
# Epoch 47/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.4291 - accuracy: 0.8519 - val_loss: 0.5621 - val_accuracy: 0.8160
# Epoch 48/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.4332 - accuracy: 0.8499 - val_loss: 0.5332 - val_accuracy: 0.8179
# Epoch 49/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.4339 - accuracy: 0.8503 - val_loss: 0.5596 - val_accuracy: 0.8157
# Epoch 50/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.4130 - accuracy: 0.8567 - val_loss: 0.5179 - val_accuracy: 0.8282
# Epoch 51/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.3985 - accuracy: 0.8627 - val_loss: 0.5276 - val_accuracy: 0.8258
# Epoch 52/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.4024 - accuracy: 0.8619 - val_loss: 0.5184 - val_accuracy: 0.8265
# Epoch 53/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.3909 - accuracy: 0.8663 - val_loss: 0.5538 - val_accuracy: 0.8175
# Epoch 54/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.3964 - accuracy: 0.8648 - val_loss: 0.5842 - val_accuracy: 0.8124
# Epoch 55/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.3776 - accuracy: 0.8696 - val_loss: 0.5001 - val_accuracy: 0.8332
# Epoch 56/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.3682 - accuracy: 0.8737 - val_loss: 0.5135 - val_accuracy: 0.8337
# Epoch 57/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.3646 - accuracy: 0.8748 - val_loss: 0.5249 - val_accuracy: 0.8345
# Epoch 58/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.3620 - accuracy: 0.8751 - val_loss: 0.5124 - val_accuracy: 0.8369
# Epoch 59/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.3563 - accuracy: 0.8791 - val_loss: 0.5492 - val_accuracy: 0.8260
# Epoch 60/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.3444 - accuracy: 0.8810 - val_loss: 0.5115 - val_accuracy: 0.8342
# Epoch 61/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.3374 - accuracy: 0.8828 - val_loss: 0.4967 - val_accuracy: 0.8370
# Epoch 62/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.3309 - accuracy: 0.8870 - val_loss: 0.4950 - val_accuracy: 0.8404
# Epoch 63/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.3130 - accuracy: 0.8927 - val_loss: 0.4946 - val_accuracy: 0.8421
# Epoch 64/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.3104 - accuracy: 0.8933 - val_loss: 0.5456 - val_accuracy: 0.8268
# Epoch 65/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.3249 - accuracy: 0.8889 - val_loss: 0.6001 - val_accuracy: 0.8166
# Epoch 66/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.3306 - accuracy: 0.8890 - val_loss: 0.5405 - val_accuracy: 0.8361
# Epoch 67/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.3102 - accuracy: 0.8944 - val_loss: 0.5071 - val_accuracy: 0.8406
# Epoch 68/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.2862 - accuracy: 0.9031 - val_loss: 0.5091 - val_accuracy: 0.8430
# Epoch 69/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.2764 - accuracy: 0.9046 - val_loss: 0.5306 - val_accuracy: 0.8398
# Epoch 70/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.2845 - accuracy: 0.9016 - val_loss: 0.5147 - val_accuracy: 0.8440
# Epoch 71/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.2724 - accuracy: 0.9064 - val_loss: 0.5521 - val_accuracy: 0.8278
# Epoch 72/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.2797 - accuracy: 0.9049 - val_loss: 0.5213 - val_accuracy: 0.8402
# Epoch 73/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.2639 - accuracy: 0.9083 - val_loss: 0.4915 - val_accuracy: 0.8505
# Epoch 74/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.2611 - accuracy: 0.9106 - val_loss: 0.5401 - val_accuracy: 0.8413
# Epoch 75/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.2627 - accuracy: 0.9096 - val_loss: 0.5275 - val_accuracy: 0.8390
# Epoch 76/300
# 79/79 [==============================] - 13s 169ms/step - loss: 0.2555 - accuracy: 0.9130 - val_loss: 0.5121 - val_accuracy: 0.8445
# Epoch 77/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.2419 - accuracy: 0.9160 - val_loss: 0.5057 - val_accuracy: 0.8486
# Epoch 78/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.2356 - accuracy: 0.9184 - val_loss: 0.5347 - val_accuracy: 0.8403
# Epoch 79/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.2501 - accuracy: 0.9143 - val_loss: 0.5039 - val_accuracy: 0.8495
# Epoch 80/300
# 79/79 [==============================] - 13s 169ms/step - loss: 0.2416 - accuracy: 0.9184 - val_loss: 0.5268 - val_accuracy: 0.8460
# Epoch 81/300
# 79/79 [==============================] - 13s 169ms/step - loss: 0.2444 - accuracy: 0.9142 - val_loss: 0.5228 - val_accuracy: 0.8419
# Epoch 82/300
# 79/79 [==============================] - 13s 169ms/step - loss: 0.2310 - accuracy: 0.9214 - val_loss: 0.5728 - val_accuracy: 0.8398
# Epoch 83/300
# 79/79 [==============================] - 13s 170ms/step - loss: 0.2362 - accuracy: 0.9194 - val_loss: 0.5185 - val_accuracy: 0.8504

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:19:10.759895

# %% [markdown]
# ## 6. Results Evaluation
#
# Let's obtain a graph of how the error and accuracy evolve at each epoch in the training and validation data.

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 84.610

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# The cost we can see that it is stable and it is at epoch 15 that it is fixed at a value. Also the accuracy dances around 0.10. We can't say that it is a very good model.
#
# Let's see what kind of predictions I'm getting on the test set (let's paint the images and their classifications)

# %%
predictions = model.predict(x_test)

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# We draw the first images, with the predictions and their real values (a total of 20 images, so as not to abuse your laptops).
#
# We color the correct predictions in blue and the failures in red. But first I have printed the labels so that we have a reference to the graph.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
