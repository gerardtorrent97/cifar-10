# %% [markdown]
# ## 1. Import Libraries

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## 2. Neural Newtork Architecture

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))


model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(32, activation="relu"))
model.add(ks.layers.Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       295168
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       295040
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         295040
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                131104
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 2,272,746
# Trainable params: 2,272,746
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Cost function

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Data Preparation
#
# We load the CIFAR10 dataset directly from Keras. Those are already split in train and test.
#
#
# **Important:**
# > The neural network requires for the inputs to be real numbers. We can simply achieve this by divinding the values inside the matrices by 255.0.

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %%
# Let's plot a sample of the images

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# When we add convolutions, we need to preprocess the data, because **convolution is for an array of 4 fields** (more like "images"), not an array of 3 dimensions as the datasets for train, test and validation. So we need to **.reshape()**.
#
# That's why, when you exit the convolution, you have to flatten the matrices, because the FullDense layers expect arrays, not matrices!

# %%
# Let's validate the results
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# # 4. Early Stopping

# %%
callback_loss = EarlyStopping(monitor="val_loss", patience=15)
callback_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)

# %% [markdown]
# ## 5. Training
#
# Note that we have to train against the data converted to the format expected by the Convolution.
#
# We will start with 30 epochs, that is to say, 30 complete passes of the dataset (which in turn will be with mini-batches internally, setting the batches to 64 elements.
#
# The .fit() method allows us to define if we have several CPUs, GPUs, and if we want to validate data at each end of epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, 
                    epochs=128, 
                    use_multiprocessing=False, 
                    batch_size= 512, 
                    callbacks=[callback_accuracy, callback_loss],
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/128
# 79/79 [==============================] - 43s 377ms/step - loss: 2.2101 - accuracy: 0.1699 - val_loss: 1.8419 - val_accuracy: 0.3280
# Epoch 2/128
# 79/79 [==============================] - 24s 302ms/step - loss: 1.7312 - accuracy: 0.3674 - val_loss: 1.4598 - val_accuracy: 0.4736
# Epoch 3/128
# 79/79 [==============================] - 24s 301ms/step - loss: 1.4180 - accuracy: 0.4838 - val_loss: 1.3026 - val_accuracy: 0.5255
# Epoch 4/128
# 79/79 [==============================] - 24s 304ms/step - loss: 1.2021 - accuracy: 0.5574 - val_loss: 1.0849 - val_accuracy: 0.6132
# Epoch 5/128
# 79/79 [==============================] - 24s 304ms/step - loss: 1.0229 - accuracy: 0.6341 - val_loss: 1.0586 - val_accuracy: 0.6309
# Epoch 6/128
# 79/79 [==============================] - 24s 303ms/step - loss: 0.8920 - accuracy: 0.6824 - val_loss: 0.9008 - val_accuracy: 0.6860
# Epoch 7/128
# 79/79 [==============================] - 24s 304ms/step - loss: 0.7713 - accuracy: 0.7272 - val_loss: 0.8624 - val_accuracy: 0.6986
# Epoch 8/128
# 79/79 [==============================] - 24s 304ms/step - loss: 0.6830 - accuracy: 0.7574 - val_loss: 0.8877 - val_accuracy: 0.6924
# Epoch 9/128
# 79/79 [==============================] - 24s 304ms/step - loss: 0.5973 - accuracy: 0.7837 - val_loss: 0.8243 - val_accuracy: 0.7151
# Epoch 10/128
# 79/79 [==============================] - 24s 304ms/step - loss: 0.5176 - accuracy: 0.8200 - val_loss: 0.8265 - val_accuracy: 0.7309
# Epoch 11/128
# 79/79 [==============================] - 24s 304ms/step - loss: 0.4362 - accuracy: 0.8464 - val_loss: 0.8178 - val_accuracy: 0.7386
# Epoch 12/128
# 79/79 [==============================] - 24s 304ms/step - loss: 0.3725 - accuracy: 0.8682 - val_loss: 0.7983 - val_accuracy: 0.7472
# Epoch 13/128
# 79/79 [==============================] - 24s 304ms/step - loss: 0.2953 - accuracy: 0.8938 - val_loss: 0.8978 - val_accuracy: 0.7490
# Epoch 14/128
# 79/79 [==============================] - 24s 304ms/step - loss: 0.2560 - accuracy: 0.9099 - val_loss: 0.8232 - val_accuracy: 0.7626
# Epoch 15/128
# 79/79 [==============================] - 24s 304ms/step - loss: 0.2030 - accuracy: 0.9287 - val_loss: 0.9949 - val_accuracy: 0.7552
# Epoch 16/128
# 79/79 [==============================] - 24s 304ms/step - loss: 0.1512 - accuracy: 0.9464 - val_loss: 1.0348 - val_accuracy: 0.7610
# Epoch 17/128
# 79/79 [==============================] - 24s 304ms/step - loss: 0.1380 - accuracy: 0.9515 - val_loss: 1.1331 - val_accuracy: 0.7560
# Epoch 18/128
# 79/79 [==============================] - 24s 304ms/step - loss: 0.1120 - accuracy: 0.9609 - val_loss: 1.2923 - val_accuracy: 0.7473
# Epoch 19/128
# 79/79 [==============================] - 24s 304ms/step - loss: 0.0988 - accuracy: 0.9658 - val_loss: 1.4488 - val_accuracy: 0.7374
# Epoch 20/128
# 79/79 [==============================] - 24s 304ms/step - loss: 0.1549 - accuracy: 0.9474 - val_loss: 1.2845 - val_accuracy: 0.7544
# Epoch 21/128
# 79/79 [==============================] - 24s 304ms/step - loss: 0.0959 - accuracy: 0.9663 - val_loss: 1.2895 - val_accuracy: 0.7546
# Epoch 22/128
# 79/79 [==============================] - 24s 304ms/step - loss: 0.0576 - accuracy: 0.9800 - val_loss: 1.4156 - val_accuracy: 0.7559
# Epoch 23/128
# 79/79 [==============================] - 24s 304ms/step - loss: 0.0900 - accuracy: 0.9691 - val_loss: 1.5786 - val_accuracy: 0.7525
# Epoch 24/128
# 79/79 [==============================] - 24s 303ms/step - loss: 0.0786 - accuracy: 0.9737 - val_loss: 1.5627 - val_accuracy: 0.7547

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:09:54.700455

# %% [markdown]
# ## 6. Results Evaluation
#
# Let's obtain a graph of how the error and accuracy evolve at each epoch in the training and validation data.

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 74.700

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# The cost we can see that it is stable and it is at epoch 15 that it is fixed at a value. Also the accuracy dances around 0.10. We can't say that it is a very good model.
#
# Let's see what kind of predictions I'm getting on the test set (let's paint the images and their classifications)

# %%
predictions = model.predict(x_test)

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# We draw the first images, with the predictions and their real values (a total of 20 images, so as not to abuse your laptops).
#
# We color the correct predictions in blue and the failures in red. But first I have printed the labels so that we have a reference to the graph.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
