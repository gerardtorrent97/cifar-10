# %% [markdown]
# ## 1. Import Libraries

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import random
import datetime

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

# %% [markdown]
# ## 2. Neural Newtork Architecture

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32, 32, 3)))
model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32, 32, 3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same",
    input_shape=(32, 32, 3)))
model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same",
    input_shape=(32, 32, 3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))


model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same",
    input_shape=(32, 32, 3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same",
    input_shape=(32, 32, 3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))



model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(512, activation="relu"))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               2097664
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 3,842,122
# Trainable params: 3,840,202
# Non-trainable params: 1,920
# _________________________________________________________________

# %% [markdown]
# ## 3. Cost function

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Data Preparation
#
# We load the CIFAR10 dataset directly from Keras. Those are already split in train and test.
#
#
# **Important:**
# > The neural network requires for the inputs to be real numbers. We can simply achieve this by divinding the values inside the matrices by 255.0.

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %%
# Let's plot a sample of the images

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# When we add convolutions, we need to preprocess the data, because **convolution is for an array of 4 fields** (more like "images"), not an array of 3 dimensions as the datasets for train, test and validation. So we need to **.reshape()**.
#
# That's why, when you exit the convolution, you have to flatten the matrices, because the FullDense layers expect arrays, not matrices!

# %%
# Let's validate the results
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# # 4. Early Stopping & Checkpoint

# %%
callback_loss = EarlyStopping(monitor="val_loss", patience=15)
callback_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)

# %%
checkpoint_filepath = '/tmp/checkpoint'
model_checkpoint_callback = ks.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %% [markdown]
# # 5. Data Augmentation

# %%
y_train_rshape = y_train.ravel()
y_val_rshape = y_val.ravel()
y_test_rshape = y_test.ravel()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(y_train_rshape)
y_train_encoded = le.transform(y_train_rshape)
y_val_encoded = le.transform(y_val_rshape)
y_test_encoded = le.transform(y_test_rshape)

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.15,
    shear_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.15,
    height_shift_range=0.15,
    brightness_range=[0.8,1.2]
    )

train_generator = train_datagen.flow(
    x_train, 
    y_train_encoded, 
    batch_size=400
)

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val, 
    y_val_encoded, 
    batch_size=100
)

test_datagen = ImageDataGenerator(
    rescale=1./255
    )
test_generator = test_datagen.flow(
    x_test, 
    y_test_encoded,
    batch_size=100
)

# %%
sample = random.choice(range(0,4999))

example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train_encoded[sample:sample+1],
    batch_size=20
)

# %%
plt.figure(figsize=(12,12))
for i in range(0,15):
  plt.subplot(5, 3, i+1)
  for X, Y in example_generator:
    image = X[0]
    plt.imshow(image)
    plt.title(Y[0])
    break
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Training
#
# Note that we have to train against the data converted to the format expected by the Convolution.
#
# We will start with 30 epochs, that is to say, 30 complete passes of the dataset (which in turn will be with mini-batches internally, setting the batches to 64 elements.
#
# The .fit() method allows us to define if we have several CPUs, GPUs, and if we want to validate data at each end of epoch.

# %%
y_train.shape
# Out:
# (40000, 1)

# %%
t = time.perf_counter()

# %%
history = model.fit(train_generator,
                    validation_data=validation_generator,
                    steps_per_epoch=100,
                    validation_steps=100,
                    epochs=300,
                    use_multiprocessing=False,
                    callbacks=[callback_accuracy, callback_loss, model_checkpoint_callback]
                    )
# Out:
# Epoch 1/300
# 100/100 [==============================] - 75s 428ms/step - loss: 2.3921 - accuracy: 0.2454 - val_loss: 4.4815 - val_accuracy: 0.0997
# Epoch 2/300
# 100/100 [==============================] - 42s 418ms/step - loss: 1.8016 - accuracy: 0.3708 - val_loss: 4.8540 - val_accuracy: 0.1024
# Epoch 3/300
# 100/100 [==============================] - 42s 417ms/step - loss: 1.6022 - accuracy: 0.4403 - val_loss: 5.0043 - val_accuracy: 0.1275
# Epoch 4/300
# 100/100 [==============================] - 41s 414ms/step - loss: 1.4473 - accuracy: 0.4928 - val_loss: 4.8110 - val_accuracy: 0.1888
# Epoch 5/300
# 100/100 [==============================] - 42s 416ms/step - loss: 1.3430 - accuracy: 0.5279 - val_loss: 2.7967 - val_accuracy: 0.2969
# Epoch 6/300
# 100/100 [==============================] - 42s 417ms/step - loss: 1.2678 - accuracy: 0.5558 - val_loss: 1.6552 - val_accuracy: 0.4654
# Epoch 7/300
# 100/100 [==============================] - 41s 413ms/step - loss: 1.1906 - accuracy: 0.5801 - val_loss: 1.3518 - val_accuracy: 0.5408
# Epoch 8/300
# 100/100 [==============================] - 42s 415ms/step - loss: 1.1172 - accuracy: 0.6102 - val_loss: 1.2592 - val_accuracy: 0.5832
# Epoch 9/300
# 100/100 [==============================] - 42s 414ms/step - loss: 1.0565 - accuracy: 0.6331 - val_loss: 1.0611 - val_accuracy: 0.6474
# Epoch 10/300
# 100/100 [==============================] - 41s 412ms/step - loss: 1.0021 - accuracy: 0.6525 - val_loss: 1.0625 - val_accuracy: 0.6442
# Epoch 11/300
# 100/100 [==============================] - 41s 410ms/step - loss: 0.9577 - accuracy: 0.6653 - val_loss: 0.9836 - val_accuracy: 0.6704
# Epoch 12/300
# 100/100 [==============================] - 41s 410ms/step - loss: 0.9090 - accuracy: 0.6803 - val_loss: 1.1131 - val_accuracy: 0.6505
# Epoch 13/300
# 100/100 [==============================] - 41s 409ms/step - loss: 0.8730 - accuracy: 0.6935 - val_loss: 0.8476 - val_accuracy: 0.7169
# Epoch 14/300
# 100/100 [==============================] - 41s 410ms/step - loss: 0.8435 - accuracy: 0.7051 - val_loss: 0.8874 - val_accuracy: 0.7109
# Epoch 15/300
# 100/100 [==============================] - 41s 409ms/step - loss: 0.8144 - accuracy: 0.7153 - val_loss: 0.8478 - val_accuracy: 0.7202
# Epoch 16/300
# 100/100 [==============================] - 41s 410ms/step - loss: 0.7926 - accuracy: 0.7233 - val_loss: 0.6744 - val_accuracy: 0.7705
# Epoch 17/300
# 100/100 [==============================] - 41s 405ms/step - loss: 0.7611 - accuracy: 0.7321 - val_loss: 0.8070 - val_accuracy: 0.7350
# Epoch 18/300
# 100/100 [==============================] - 41s 409ms/step - loss: 0.7472 - accuracy: 0.7372 - val_loss: 0.7446 - val_accuracy: 0.7546
# Epoch 19/300
# 100/100 [==============================] - 41s 409ms/step - loss: 0.7248 - accuracy: 0.7481 - val_loss: 0.7630 - val_accuracy: 0.7496
# Epoch 20/300
# 100/100 [==============================] - 40s 404ms/step - loss: 0.7129 - accuracy: 0.7515 - val_loss: 0.8809 - val_accuracy: 0.7324
# Epoch 21/300
# 100/100 [==============================] - 41s 406ms/step - loss: 0.6964 - accuracy: 0.7576 - val_loss: 0.6058 - val_accuracy: 0.7958
# Epoch 22/300
# 100/100 [==============================] - 41s 404ms/step - loss: 0.6734 - accuracy: 0.7659 - val_loss: 0.6574 - val_accuracy: 0.7790
# Epoch 23/300
# 100/100 [==============================] - 41s 405ms/step - loss: 0.6586 - accuracy: 0.7710 - val_loss: 0.6768 - val_accuracy: 0.7785
# Epoch 24/300
# 100/100 [==============================] - 41s 404ms/step - loss: 0.6488 - accuracy: 0.7735 - val_loss: 0.5860 - val_accuracy: 0.8014
# Epoch 25/300
# 100/100 [==============================] - 41s 406ms/step - loss: 0.3823 - accuracy: 0.8674 - val_loss: 0.4269 - val_accuracy: 0.8616
# Epoch 68/300
# 100/100 [==============================] - 41s 405ms/step - loss: 0.3769 - accuracy: 0.8682 - val_loss: 0.4376 - val_accuracy: 0.8594
# Epoch 69/300
# 100/100 [==============================] - 41s 404ms/step - loss: 0.3733 - accuracy: 0.8719 - val_loss: 0.4586 - val_accuracy: 0.8579
# Epoch 70/300
# 100/100 [==============================] - 40s 403ms/step - loss: 0.3702 - accuracy: 0.8693 - val_loss: 0.3625 - val_accuracy: 0.8817
# Epoch 71/300
# 100/100 [==============================] - 40s 404ms/step - loss: 0.3704 - accuracy: 0.8723 - val_loss: 0.3678 - val_accuracy: 0.8801
# Epoch 72/300
# 100/100 [==============================] - 40s 401ms/step - loss: 0.3575 - accuracy: 0.8756 - val_loss: 0.4014 - val_accuracy: 0.8677
# Epoch 73/300
# 100/100 [==============================] - 40s 400ms/step - loss: 0.3569 - accuracy: 0.8780 - val_loss: 0.4343 - val_accuracy: 0.8606
# Epoch 74/300
# 100/100 [==============================] - 40s 404ms/step - loss: 0.3562 - accuracy: 0.8738 - val_loss: 0.3649 - val_accuracy: 0.8805
# Epoch 75/300
# 100/100 [==============================] - 41s 407ms/step - loss: 0.3527 - accuracy: 0.8773 - val_loss: 0.3993 - val_accuracy: 0.8728
# Epoch 76/300
# 100/100 [==============================] - 40s 402ms/step - loss: 0.3488 - accuracy: 0.8779 - val_loss: 0.4126 - val_accuracy: 0.8664
# Epoch 77/300
# 100/100 [==============================] - 41s 404ms/step - loss: 0.3453 - accuracy: 0.8801 - val_loss: 0.3854 - val_accuracy: 0.8760
# Epoch 78/300
# 100/100 [==============================] - 40s 402ms/step - loss: 0.3446 - accuracy: 0.8798 - val_loss: 0.4319 - val_accuracy: 0.8628
# Epoch 79/300
# 100/100 [==============================] - 40s 403ms/step - loss: 0.3351 - accuracy: 0.8833 - val_loss: 0.4356 - val_accuracy: 0.8595
# Epoch 80/300
# 100/100 [==============================] - 40s 403ms/step - loss: 0.3390 - accuracy: 0.8806 - val_loss: 0.3585 - val_accuracy: 0.8850
# Epoch 81/300
# 100/100 [==============================] - 40s 404ms/step - loss: 0.3362 - accuracy: 0.8825 - val_loss: 0.3772 - val_accuracy: 0.8772
# Epoch 82/300
# 100/100 [==============================] - 41s 407ms/step - loss: 0.3376 - accuracy: 0.8821 - val_loss: 0.4128 - val_accuracy: 0.8666
# Epoch 83/300
# 100/100 [==============================] - 41s 407ms/step - loss: 0.3318 - accuracy: 0.8841 - val_loss: 0.3532 - val_accuracy: 0.8848
# Epoch 84/300
# 100/100 [==============================] - 40s 404ms/step - loss: 0.3279 - accuracy: 0.8867 - val_loss: 0.3788 - val_accuracy: 0.8833
# Epoch 85/300
# 100/100 [==============================] - 40s 404ms/step - loss: 0.3268 - accuracy: 0.8855 - val_loss: 0.3977 - val_accuracy: 0.8731
# Epoch 86/300
# 100/100 [==============================] - 40s 404ms/step - loss: 0.3176 - accuracy: 0.8878 - val_loss: 0.4369 - val_accuracy: 0.8645
# Epoch 87/300
# 100/100 [==============================] - 41s 406ms/step - loss: 0.3180 - accuracy: 0.8907 - val_loss: 0.4733 - val_accuracy: 0.8549
# Epoch 88/300
# 100/100 [==============================] - 40s 402ms/step - loss: 0.3215 - accuracy: 0.8859 - val_loss: 0.3449 - val_accuracy: 0.8885
# Epoch 89/300
# 100/100 [==============================] - 41s 408ms/step - loss: 0.3167 - accuracy: 0.8902 - val_loss: 0.3636 - val_accuracy: 0.8836
# Epoch 90/300
# 100/100 [==============================] - 40s 404ms/step - loss: 0.3182 - accuracy: 0.8890 - val_loss: 0.4321 - val_accuracy: 0.8643
# Epoch 91/300
# 100/100 [==============================] - 41s 405ms/step - loss: 0.3106 - accuracy: 0.8923 - val_loss: 0.3850 - val_accuracy: 0.8771
# Epoch 92/300
# 100/100 [==============================] - 40s 404ms/step - loss: 0.3102 - accuracy: 0.8923 - val_loss: 0.3863 - val_accuracy: 0.8818
# Epoch 93/300
# 100/100 [==============================] - 41s 406ms/step - loss: 0.3163 - accuracy: 0.8907 - val_loss: 0.3260 - val_accuracy: 0.8930
# Epoch 94/300
# 100/100 [==============================] - 41s 410ms/step - loss: 0.3115 - accuracy: 0.8901 - val_loss: 0.3212 - val_accuracy: 0.8940
# Epoch 95/300
# 100/100 [==============================] - 41s 405ms/step - loss: 0.2998 - accuracy: 0.8949 - val_loss: 0.3400 - val_accuracy: 0.8880
# Epoch 96/300
# 100/100 [==============================] - 41s 406ms/step - loss: 0.3016 - accuracy: 0.8939 - val_loss: 0.3672 - val_accuracy: 0.8833
# Epoch 97/300
# 100/100 [==============================] - 41s 408ms/step - loss: 0.2949 - accuracy: 0.8964 - val_loss: 0.4696 - val_accuracy: 0.8553
# Epoch 98/300
# 100/100 [==============================] - 40s 404ms/step - loss: 0.2966 - accuracy: 0.8964 - val_loss: 0.3782 - val_accuracy: 0.8799
# Epoch 99/300
# 100/100 [==============================] - 41s 405ms/step - loss: 0.2964 - accuracy: 0.8960 - val_loss: 0.3746 - val_accuracy: 0.8801
# Epoch 100/300
# 100/100 [==============================] - 40s 403ms/step - loss: 0.2899 - accuracy: 0.8987 - val_loss: 0.3482 - val_accuracy: 0.8864
# Epoch 101/300
# 100/100 [==============================] - 40s 403ms/step - loss: 0.2937 - accuracy: 0.8982 - val_loss: 0.3746 - val_accuracy: 0.8807
# Epoch 102/300
# 100/100 [==============================] - 40s 404ms/step - loss: 0.2929 - accuracy: 0.8948 - val_loss: 0.3503 - val_accuracy: 0.8864
# Epoch 103/300
# 100/100 [==============================] - 40s 403ms/step - loss: 0.2905 - accuracy: 0.8971 - val_loss: 0.5246 - val_accuracy: 0.8449
# Epoch 104/300
# 100/100 [==============================] - 41s 412ms/step - loss: 0.2846 - accuracy: 0.9007 - val_loss: 0.3539 - val_accuracy: 0.8879

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 1:11:21.908287

# %%
model.load_weights(checkpoint_filepath)

# %% [markdown]
# ## 6. Results Evaluation
#
# Let's obtain a graph of how the error and accuracy evolve at each epoch in the training and validation data.

# %%
_, acc = model.evaluate(test_generator, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 89.220

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# The cost we can see that it is stable and it is at epoch 15 that it is fixed at a value. Also the accuracy dances around 0.10. We can't say that it is a very good model.
#
# Let's see what kind of predictions I'm getting on the test set (let's paint the images and their classifications)

# %%
predictions = model.predict(x_test)

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# We draw the first images, with the predictions and their real values (a total of 20 images, so as not to abuse your laptops).
#
# We color the correct predictions in blue and the failures in red. But first I have printed the labels so that we have a reference to the graph.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
