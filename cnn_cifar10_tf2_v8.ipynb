# %% [markdown]
# ## 1. Import Libraries

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import random
import datetime

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

# %% [markdown]
# ## 2. Neural Newtork Architecture

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32, 32, 3)))
model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32, 32, 3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same",
    input_shape=(32, 32, 3)))
model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same",
    input_shape=(32, 32, 3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))


model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same",
    input_shape=(32, 32, 3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same",
    input_shape=(32, 32, 3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))



model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(1024, activation="relu"))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              4195328
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 5,946,954
# Trainable params: 5,944,010
# Non-trainable params: 2,944
# _________________________________________________________________

# %% [markdown]
# ## 3. Cost function

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Data Preparation
#
# We load the CIFAR10 dataset directly from Keras. Those are already split in train and test.
#
#
# **Important:**
# > The neural network requires for the inputs to be real numbers. We can simply achieve this by divinding the values inside the matrices by 255.0.

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %%
# Let's plot a sample of the images

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# When we add convolutions, we need to preprocess the data, because **convolution is for an array of 4 fields** (more like "images"), not an array of 3 dimensions as the datasets for train, test and validation. So we need to **.reshape()**.
#
# That's why, when you exit the convolution, you have to flatten the matrices, because the FullDense layers expect arrays, not matrices!

# %%
# Let's validate the results
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# # 4. Early Stopping & Checkpoint

# %%
callback_loss = EarlyStopping(monitor="val_loss", patience=15)
callback_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)

# %%
checkpoint_filepath = '/tmp/checkpoint'
model_checkpoint_callback = ks.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %% [markdown]
# # 5. Data Augmentation

# %%
y_train_rshape = y_train.ravel()
y_val_rshape = y_val.ravel()
y_test_rshape = y_test.ravel()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(y_train_rshape)
y_train_encoded = le.transform(y_train_rshape)
y_val_encoded = le.transform(y_val_rshape)
y_test_encoded = le.transform(y_test_rshape)

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.15,
    shear_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.15,
    height_shift_range=0.15,
    brightness_range=[0.8,1.2]
    )

train_generator = train_datagen.flow(
    x_train, 
    y_train_encoded, 
    batch_size=400
)

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val, 
    y_val_encoded, 
    batch_size=100
)

test_datagen = ImageDataGenerator(
    rescale=1./255
    )
test_generator = test_datagen.flow(
    x_test, 
    y_test_encoded,
    batch_size=100
)

# %%
sample = random.choice(range(0,4999))

example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train_encoded[sample:sample+1],
    batch_size=20
)

# %%
plt.figure(figsize=(12,12))
for i in range(0,15):
  plt.subplot(5, 3, i+1)
  for X, Y in example_generator:
    image = X[0]
    plt.imshow(image)
    plt.title(Y[0])
    break
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Training
#
# Note that we have to train against the data converted to the format expected by the Convolution.
#
# We will start with 30 epochs, that is to say, 30 complete passes of the dataset (which in turn will be with mini-batches internally, setting the batches to 64 elements.
#
# The .fit() method allows us to define if we have several CPUs, GPUs, and if we want to validate data at each end of epoch.

# %%
y_train.shape
# Out:
# (40000, 1)

# %%
t = time.perf_counter()

# %%
history = model.fit(train_generator,
                    validation_data=validation_generator,
                    steps_per_epoch=100,
                    validation_steps=100,
                    epochs=300,
                    use_multiprocessing=False,
                    callbacks=[callback_accuracy, callback_loss, model_checkpoint_callback]
                    )
# Out:
# Epoch 1/300
# 100/100 [==============================] - 33s 275ms/step - loss: 2.3879 - accuracy: 0.2541 - val_loss: 4.5019 - val_accuracy: 0.0998
# Epoch 2/300
# 100/100 [==============================] - 28s 277ms/step - loss: 1.8235 - accuracy: 0.3743 - val_loss: 3.4202 - val_accuracy: 0.1188
# Epoch 3/300
# 100/100 [==============================] - 27s 272ms/step - loss: 1.6198 - accuracy: 0.4437 - val_loss: 4.2578 - val_accuracy: 0.1205
# Epoch 4/300
# 100/100 [==============================] - 27s 269ms/step - loss: 1.4814 - accuracy: 0.4882 - val_loss: 2.8277 - val_accuracy: 0.2283
# Epoch 5/300
# 100/100 [==============================] - 27s 270ms/step - loss: 1.3648 - accuracy: 0.5285 - val_loss: 2.3211 - val_accuracy: 0.3147
# Epoch 6/300
# 100/100 [==============================] - 27s 268ms/step - loss: 1.2866 - accuracy: 0.5598 - val_loss: 2.1474 - val_accuracy: 0.4070
# Epoch 7/300
# 100/100 [==============================] - 27s 268ms/step - loss: 1.1945 - accuracy: 0.5903 - val_loss: 1.1860 - val_accuracy: 0.6077
# Epoch 8/300
# 100/100 [==============================] - 27s 269ms/step - loss: 1.1364 - accuracy: 0.6119 - val_loss: 0.9649 - val_accuracy: 0.6723
# Epoch 9/300
# 100/100 [==============================] - 27s 267ms/step - loss: 1.0720 - accuracy: 0.6323 - val_loss: 1.0688 - val_accuracy: 0.6579
# Epoch 10/300
# 100/100 [==============================] - 27s 267ms/step - loss: 1.0048 - accuracy: 0.6575 - val_loss: 1.3304 - val_accuracy: 0.5767
# Epoch 11/300
# 100/100 [==============================] - 27s 269ms/step - loss: 0.9774 - accuracy: 0.6678 - val_loss: 0.9301 - val_accuracy: 0.6828
# Epoch 12/300
# 100/100 [==============================] - 27s 268ms/step - loss: 0.9351 - accuracy: 0.6844 - val_loss: 1.1175 - val_accuracy: 0.6328
# Epoch 13/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.9101 - accuracy: 0.6918 - val_loss: 0.7915 - val_accuracy: 0.7357
# Epoch 14/300
# 100/100 [==============================] - 27s 269ms/step - loss: 0.8643 - accuracy: 0.7058 - val_loss: 0.8057 - val_accuracy: 0.7358
# Epoch 15/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.8326 - accuracy: 0.7147 - val_loss: 0.8015 - val_accuracy: 0.7268
# Epoch 16/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.8073 - accuracy: 0.7238 - val_loss: 0.9739 - val_accuracy: 0.6939
# Epoch 17/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.7698 - accuracy: 0.7343 - val_loss: 0.7332 - val_accuracy: 0.7559
# Epoch 18/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.7490 - accuracy: 0.7401 - val_loss: 0.6163 - val_accuracy: 0.7888
# Epoch 19/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.7186 - accuracy: 0.7497 - val_loss: 0.6605 - val_accuracy: 0.7768
# Epoch 20/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.6984 - accuracy: 0.7577 - val_loss: 0.6496 - val_accuracy: 0.7818
# Epoch 21/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.6776 - accuracy: 0.7648 - val_loss: 0.5814 - val_accuracy: 0.8081
# Epoch 22/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.6708 - accuracy: 0.7666 - val_loss: 0.6610 - val_accuracy: 0.7827
# Epoch 23/300
# 100/100 [==============================] - 27s 268ms/step - loss: 0.6596 - accuracy: 0.7738 - val_loss: 0.5894 - val_accuracy: 0.7968
# Epoch 24/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.6489 - accuracy: 0.7744 - val_loss: 0.7104 - val_accuracy: 0.7736
# Epoch 25/300
# 100/100 [==============================] - 27s 265ms/step - loss: 0.6282 - accuracy: 0.7825 - val_loss: 0.7011 - val_accuracy: 0.7815
# Epoch 26/300
# 100/100 [==============================] - 27s 268ms/step - loss: 0.6127 - accuracy: 0.7884 - val_loss: 0.5840 - val_accuracy: 0.8119
# Epoch 27/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.6084 - accuracy: 0.7897 - val_loss: 0.5540 - val_accuracy: 0.8145
# Epoch 28/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.6015 - accuracy: 0.7902 - val_loss: 0.5284 - val_accuracy: 0.8185
# Epoch 29/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.5875 - accuracy: 0.7983 - val_loss: 0.5114 - val_accuracy: 0.8264
# Epoch 30/300
# 100/100 [==============================] - 27s 265ms/step - loss: 0.5785 - accuracy: 0.7999 - val_loss: 0.6243 - val_accuracy: 0.7994
# Epoch 31/300
# 100/100 [==============================] - 27s 265ms/step - loss: 0.5692 - accuracy: 0.8005 - val_loss: 0.5095 - val_accuracy: 0.8299
# Epoch 32/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.5639 - accuracy: 0.8044 - val_loss: 0.4922 - val_accuracy: 0.8369
# Epoch 33/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.5585 - accuracy: 0.8070 - val_loss: 0.6146 - val_accuracy: 0.8119
# Epoch 34/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.5446 - accuracy: 0.8112 - val_loss: 0.5593 - val_accuracy: 0.8157
# Epoch 35/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.5358 - accuracy: 0.8150 - val_loss: 0.4677 - val_accuracy: 0.8437
# Epoch 36/300
# 100/100 [==============================] - 27s 268ms/step - loss: 0.5245 - accuracy: 0.8171 - val_loss: 0.5312 - val_accuracy: 0.8214
# Epoch 37/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.5195 - accuracy: 0.8193 - val_loss: 0.5468 - val_accuracy: 0.8232
# Epoch 38/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.5242 - accuracy: 0.8184 - val_loss: 0.5428 - val_accuracy: 0.8230
# Epoch 39/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.5112 - accuracy: 0.8224 - val_loss: 0.5063 - val_accuracy: 0.8323
# Epoch 40/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.4971 - accuracy: 0.8263 - val_loss: 0.4292 - val_accuracy: 0.8559
# Epoch 41/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.4923 - accuracy: 0.8281 - val_loss: 0.4826 - val_accuracy: 0.8378
# Epoch 42/300
# 100/100 [==============================] - 27s 265ms/step - loss: 0.4867 - accuracy: 0.8296 - val_loss: 0.5305 - val_accuracy: 0.8315
# Epoch 43/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.4761 - accuracy: 0.8321 - val_loss: 0.5619 - val_accuracy: 0.8225
# Epoch 44/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.4800 - accuracy: 0.8327 - val_loss: 0.4588 - val_accuracy: 0.8477
# Epoch 45/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.4706 - accuracy: 0.8356 - val_loss: 0.5313 - val_accuracy: 0.8281
# Epoch 46/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.4647 - accuracy: 0.8390 - val_loss: 0.4691 - val_accuracy: 0.8423
# Epoch 47/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.4606 - accuracy: 0.8398 - val_loss: 0.4510 - val_accuracy: 0.8499
# Epoch 48/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.4514 - accuracy: 0.8430 - val_loss: 0.5307 - val_accuracy: 0.8260
# Epoch 49/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.4454 - accuracy: 0.8451 - val_loss: 0.4155 - val_accuracy: 0.8630
# Epoch 50/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.4403 - accuracy: 0.8482 - val_loss: 0.5136 - val_accuracy: 0.8316
# Epoch 51/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.4356 - accuracy: 0.8487 - val_loss: 0.5640 - val_accuracy: 0.8240
# Epoch 52/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.4386 - accuracy: 0.8456 - val_loss: 0.4049 - val_accuracy: 0.8680
# Epoch 53/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.4341 - accuracy: 0.8489 - val_loss: 0.3851 - val_accuracy: 0.8716
# Epoch 54/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.4279 - accuracy: 0.8511 - val_loss: 0.4276 - val_accuracy: 0.8600
# Epoch 55/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.4154 - accuracy: 0.8556 - val_loss: 0.5303 - val_accuracy: 0.8332
# Epoch 56/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.4152 - accuracy: 0.8546 - val_loss: 0.4671 - val_accuracy: 0.8465
# Epoch 57/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.4126 - accuracy: 0.8557 - val_loss: 0.4283 - val_accuracy: 0.8587
# Epoch 58/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.4137 - accuracy: 0.8579 - val_loss: 0.3975 - val_accuracy: 0.8701
# Epoch 59/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.4049 - accuracy: 0.8586 - val_loss: 0.3832 - val_accuracy: 0.8761
# Epoch 60/300
# 100/100 [==============================] - 27s 268ms/step - loss: 0.4014 - accuracy: 0.8605 - val_loss: 0.3990 - val_accuracy: 0.8692
# Epoch 61/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.3956 - accuracy: 0.8622 - val_loss: 0.4515 - val_accuracy: 0.8543
# Epoch 62/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.3964 - accuracy: 0.8614 - val_loss: 0.4120 - val_accuracy: 0.8649
# Epoch 63/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.3904 - accuracy: 0.8649 - val_loss: 0.4551 - val_accuracy: 0.8539
# Epoch 64/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.3852 - accuracy: 0.8645 - val_loss: 0.5398 - val_accuracy: 0.8416
# Epoch 65/300
# 100/100 [==============================] - 27s 269ms/step - loss: 0.3876 - accuracy: 0.8645 - val_loss: 0.3554 - val_accuracy: 0.8804
# Epoch 66/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.3842 - accuracy: 0.8676 - val_loss: 0.4117 - val_accuracy: 0.8641
# Epoch 67/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.3753 - accuracy: 0.8687 - val_loss: 0.4335 - val_accuracy: 0.8614
# Epoch 68/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.3795 - accuracy: 0.8689 - val_loss: 0.3914 - val_accuracy: 0.8745
# Epoch 69/300
# 100/100 [==============================] - 27s 265ms/step - loss: 0.3696 - accuracy: 0.8713 - val_loss: 0.4462 - val_accuracy: 0.8615
# Epoch 70/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.3684 - accuracy: 0.8712 - val_loss: 0.4477 - val_accuracy: 0.8585
# Epoch 71/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.3577 - accuracy: 0.8760 - val_loss: 0.4349 - val_accuracy: 0.8599
# Epoch 72/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.3639 - accuracy: 0.8716 - val_loss: 0.4184 - val_accuracy: 0.8631
# Epoch 73/300
# 100/100 [==============================] - 27s 266ms/step - loss: 0.3586 - accuracy: 0.8752 - val_loss: 0.4455 - val_accuracy: 0.8586
# Epoch 74/300
# 100/100 [==============================] - 27s 267ms/step - loss: 0.3561 - accuracy: 0.8758 - val_loss: 0.4042 - val_accuracy: 0.8673
# Epoch 75/300
# 100/100 [==============================] - 27s 265ms/step - loss: 0.3484 - accuracy: 0.8800 - val_loss: 0.3886 - val_accuracy: 0.8767

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:33:51.606354

# %%
model.load_weights(checkpoint_filepath)

# %% [markdown]
# ## 6. Results Evaluation
#
# Let's obtain a graph of how the error and accuracy evolve at each epoch in the training and validation data.

# %%
_, acc = model.evaluate(test_generator, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 88.020

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# The cost we can see that it is stable and it is at epoch 15 that it is fixed at a value. Also the accuracy dances around 0.10. We can't say that it is a very good model.
#
# Let's see what kind of predictions I'm getting on the test set (let's paint the images and their classifications)

# %%
predictions = model.predict(x_test)

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# We draw the first images, with the predictions and their real values (a total of 20 images, so as not to abuse your laptops).
#
# We color the correct predictions in blue and the failures in red. But first I have printed the labels so that we have a reference to the graph.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
