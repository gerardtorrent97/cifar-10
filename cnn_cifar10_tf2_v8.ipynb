# %% [markdown]
# ## 1. Import Libraries

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from tensorflow.keras.regularizers import l2

# %% [markdown]
# ## 2. Neural Newtork Architecture

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.35))

model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.35))


model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.35))



model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(512, activation="relu"))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(512, activation="relu"))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(512, activation="relu"))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               2097664
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 4,371,530
# Trainable params: 4,367,562
# Non-trainable params: 3,968
# _________________________________________________________________

# %% [markdown]
# ## 3. Cost function

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Data Preparation
#
# We load the CIFAR10 dataset directly from Keras. Those are already split in train and test.
#
#
# **Important:**
# > The neural network requires for the inputs to be real numbers. We can simply achieve this by divinding the values inside the matrices by 255.0.

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %%
# Let's plot a sample of the images

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# When we add convolutions, we need to preprocess the data, because **convolution is for an array of 4 fields** (more like "images"), not an array of 3 dimensions as the datasets for train, test and validation. So we need to **.reshape()**.
#
# That's why, when you exit the convolution, you have to flatten the matrices, because the FullDense layers expect arrays, not matrices!

# %%
# Let's validate the results
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# # Early Stopping

# %%
callback_loss = EarlyStopping(monitor="val_loss", patience=15)
callback_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)

# %%
y_tr

# %% [markdown]
# # Data Augmentation

# %%
WIDTH=150
HEIGHT=150
IMAGE_SIZE=(WIDTH, HEIGHT)
CHANNELS=3

# %% [markdown]
# ## 5. Training
#
# Note that we have to train against the data converted to the format expected by the Convolution.
#
# We will start with 30 epochs, that is to say, 30 complete passes of the dataset (which in turn will be with mini-batches internally, setting the batches to 64 elements.
#
# The .fit() method allows us to define if we have several CPUs, GPUs, and if we want to validate data at each end of epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, 
                    epochs=300, 
                    use_multiprocessing=False, 
                    batch_size= 512, 
                    callbacks=[callback_accuracy, callback_loss],
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/300
# 79/79 [==============================] - 27s 263ms/step - loss: 2.8956 - accuracy: 0.1770 - val_loss: 8.0984 - val_accuracy: 0.0997
# Epoch 2/300
# 79/79 [==============================] - 18s 233ms/step - loss: 1.9146 - accuracy: 0.3298 - val_loss: 6.5204 - val_accuracy: 0.1211
# Epoch 3/300
# 79/79 [==============================] - 18s 233ms/step - loss: 1.6128 - accuracy: 0.4168 - val_loss: 7.7421 - val_accuracy: 0.1000
# Epoch 4/300
# 79/79 [==============================] - 18s 232ms/step - loss: 1.4233 - accuracy: 0.4873 - val_loss: 8.7600 - val_accuracy: 0.1039
# Epoch 5/300
# 79/79 [==============================] - 18s 232ms/step - loss: 1.2740 - accuracy: 0.5473 - val_loss: 7.2327 - val_accuracy: 0.1485
# Epoch 6/300
# 79/79 [==============================] - 18s 233ms/step - loss: 1.1177 - accuracy: 0.5976 - val_loss: 4.1578 - val_accuracy: 0.2365
# Epoch 7/300
# 79/79 [==============================] - 18s 232ms/step - loss: 1.0161 - accuracy: 0.6393 - val_loss: 2.4770 - val_accuracy: 0.3578
# Epoch 8/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.9261 - accuracy: 0.6745 - val_loss: 1.0656 - val_accuracy: 0.6448
# Epoch 9/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.8350 - accuracy: 0.7129 - val_loss: 1.0785 - val_accuracy: 0.6275
# Epoch 10/300
# 79/79 [==============================] - 18s 233ms/step - loss: 0.7713 - accuracy: 0.7302 - val_loss: 0.8998 - val_accuracy: 0.6986
# Epoch 11/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.7096 - accuracy: 0.7550 - val_loss: 0.7013 - val_accuracy: 0.7572
# Epoch 12/300
# 79/79 [==============================] - 18s 231ms/step - loss: 0.6630 - accuracy: 0.7719 - val_loss: 0.9068 - val_accuracy: 0.7085
# Epoch 13/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.6077 - accuracy: 0.7937 - val_loss: 0.7203 - val_accuracy: 0.7580
# Epoch 14/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.5727 - accuracy: 0.8065 - val_loss: 0.7399 - val_accuracy: 0.7605
# Epoch 15/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.5603 - accuracy: 0.8092 - val_loss: 0.7530 - val_accuracy: 0.7597
# Epoch 16/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.5078 - accuracy: 0.8272 - val_loss: 0.6228 - val_accuracy: 0.7978
# Epoch 17/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.4916 - accuracy: 0.8311 - val_loss: 0.8410 - val_accuracy: 0.7419
# Epoch 18/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.4500 - accuracy: 0.8476 - val_loss: 0.6304 - val_accuracy: 0.8027
# Epoch 19/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.4244 - accuracy: 0.8552 - val_loss: 0.6693 - val_accuracy: 0.7895
# Epoch 20/300
# 79/79 [==============================] - 18s 231ms/step - loss: 0.3833 - accuracy: 0.8718 - val_loss: 0.7606 - val_accuracy: 0.7791
# Epoch 21/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.3734 - accuracy: 0.8727 - val_loss: 0.6799 - val_accuracy: 0.7914
# Epoch 22/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.3712 - accuracy: 0.8733 - val_loss: 0.6056 - val_accuracy: 0.8191
# Epoch 23/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.3764 - accuracy: 0.8721 - val_loss: 0.6760 - val_accuracy: 0.7972
# Epoch 24/300
# 79/79 [==============================] - 18s 231ms/step - loss: 0.3174 - accuracy: 0.8912 - val_loss: 0.6251 - val_accuracy: 0.8147
# Epoch 25/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.2980 - accuracy: 0.9009 - val_loss: 0.7052 - val_accuracy: 0.8019
# Epoch 26/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.2739 - accuracy: 0.9074 - val_loss: 0.5639 - val_accuracy: 0.8308
# Epoch 27/300
# 79/79 [==============================] - 18s 231ms/step - loss: 0.2916 - accuracy: 0.8997 - val_loss: 0.6187 - val_accuracy: 0.8213
# Epoch 28/300
# 79/79 [==============================] - 18s 231ms/step - loss: 0.2605 - accuracy: 0.9109 - val_loss: 0.6018 - val_accuracy: 0.8297
# Epoch 29/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.2640 - accuracy: 0.9101 - val_loss: 0.5652 - val_accuracy: 0.8374
# Epoch 30/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.2251 - accuracy: 0.9232 - val_loss: 0.5739 - val_accuracy: 0.8368
# Epoch 31/300
# 79/79 [==============================] - 18s 231ms/step - loss: 0.2222 - accuracy: 0.9245 - val_loss: 0.5769 - val_accuracy: 0.8412
# Epoch 32/300
# 79/79 [==============================] - 18s 231ms/step - loss: 0.2413 - accuracy: 0.9165 - val_loss: 0.5894 - val_accuracy: 0.8357
# Epoch 33/300
# 79/79 [==============================] - 18s 231ms/step - loss: 0.2013 - accuracy: 0.9322 - val_loss: 0.6070 - val_accuracy: 0.8292
# Epoch 34/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.1861 - accuracy: 0.9377 - val_loss: 0.5851 - val_accuracy: 0.8395
# Epoch 35/300
# 79/79 [==============================] - 18s 231ms/step - loss: 0.1797 - accuracy: 0.9394 - val_loss: 0.6404 - val_accuracy: 0.8271
# Epoch 36/300
# 79/79 [==============================] - 18s 231ms/step - loss: 0.1655 - accuracy: 0.9428 - val_loss: 0.5719 - val_accuracy: 0.8484
# Epoch 37/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.1496 - accuracy: 0.9487 - val_loss: 0.7496 - val_accuracy: 0.8153
# Epoch 38/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.1995 - accuracy: 0.9318 - val_loss: 0.5690 - val_accuracy: 0.8483
# Epoch 39/300
# 79/79 [==============================] - 18s 232ms/step - loss: 0.1514 - accuracy: 0.9482 - val_loss: 0.7768 - val_accuracy: 0.8119
# Epoch 40/300
# 79/79 [==============================] - 18s 231ms/step - loss: 0.1784 - accuracy: 0.9384 - val_loss: 0.6098 - val_accuracy: 0.8468
# Epoch 41/300
# 79/79 [==============================] - 18s 231ms/step - loss: 0.1242 - accuracy: 0.9568 - val_loss: 0.6489 - val_accuracy: 0.8370

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:12:40.274796

# %% [markdown]
# ## 6. Results Evaluation
#
# Let's obtain a graph of how the error and accuracy evolve at each epoch in the training and validation data.

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 83.740

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# The cost we can see that it is stable and it is at epoch 15 that it is fixed at a value. Also the accuracy dances around 0.10. We can't say that it is a very good model.
#
# Let's see what kind of predictions I'm getting on the test set (let's paint the images and their classifications)

# %%
predictions = model.predict(x_test)

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# We draw the first images, with the predictions and their real values (a total of 20 images, so as not to abuse your laptops).
#
# We color the correct predictions in blue and the failures in red. But first I have printed the labels so that we have a reference to the graph.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
