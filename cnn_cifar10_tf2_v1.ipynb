# %% [markdown]
# ## 1. Import Libraries

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## 2. Neural Newtork Architecture

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(
    filters=32, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(32, activation="relu"))
model.add(ks.layers.Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                131104
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 150,826
# Trainable params: 150,826
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Cost function

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Data Preparation
#
# We load the CIFAR10 dataset directly from Keras. Those are already split in train and test.
#
#
# **Important:**
# > The neural network requires for the inputs to be real numbers. We can simply achieve this by divinding the values inside the matrices by 255.0.

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %%
# Let's plot a sample of the images

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# When we add convolutions, we need to preprocess the data, because **convolution is for an array of 4 fields** (more like "images"), not an array of 3 dimensions as the datasets for train, test and validation. So we need to **.reshape()**.
#
# That's why, when you exit the convolution, you have to flatten the matrices, because the FullDense layers expect arrays, not matrices!

# %%
# Let's validate the results
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# # 4. Early Stopping

# %%
callback_loss = EarlyStopping(monitor="val_loss", patience=10)
callback_accuracy = EarlyStopping(monitor="val_accuracy", patience=5)

# %% [markdown]
# ## 5. Training
#
# Note that we have to train against the data converted to the format expected by the Convolution.
#
# We will start with 30 epochs, that is to say, 30 complete passes of the dataset (which in turn will be with mini-batches internally, setting the batches to 64 elements.
#
# The .fit() method allows us to define if we have several CPUs, GPUs, and if we want to validate data at each end of epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, 
                    epochs=128, 
                    use_multiprocessing=False, 
                    batch_size= 512, 
                    callbacks=[callback_accuracy, callback_loss],
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/128
# 79/79 [==============================] - 5s 27ms/step - loss: 2.1903 - accuracy: 0.1879 - val_loss: 1.7938 - val_accuracy: 0.3531
# Epoch 2/128
# 79/79 [==============================] - 2s 19ms/step - loss: 1.7020 - accuracy: 0.3945 - val_loss: 1.5725 - val_accuracy: 0.4367
# Epoch 3/128
# 79/79 [==============================] - 2s 20ms/step - loss: 1.5077 - accuracy: 0.4633 - val_loss: 1.4852 - val_accuracy: 0.4719
# Epoch 4/128
# 79/79 [==============================] - 2s 20ms/step - loss: 1.3905 - accuracy: 0.5051 - val_loss: 1.4001 - val_accuracy: 0.5139
# Epoch 5/128
# 79/79 [==============================] - 2s 20ms/step - loss: 1.3064 - accuracy: 0.5355 - val_loss: 1.2731 - val_accuracy: 0.5527
# Epoch 6/128
# 79/79 [==============================] - 2s 20ms/step - loss: 1.2370 - accuracy: 0.5658 - val_loss: 1.2665 - val_accuracy: 0.5631
# Epoch 7/128
# 79/79 [==============================] - 2s 19ms/step - loss: 1.1856 - accuracy: 0.5831 - val_loss: 1.1976 - val_accuracy: 0.5837
# Epoch 8/128
# 79/79 [==============================] - 2s 20ms/step - loss: 1.1438 - accuracy: 0.5959 - val_loss: 1.1643 - val_accuracy: 0.5943
# Epoch 9/128
# 79/79 [==============================] - 2s 20ms/step - loss: 1.1198 - accuracy: 0.6101 - val_loss: 1.2065 - val_accuracy: 0.5762
# Epoch 10/128
# 79/79 [==============================] - 2s 20ms/step - loss: 1.1027 - accuracy: 0.6124 - val_loss: 1.1608 - val_accuracy: 0.5958
# Epoch 11/128
# 79/79 [==============================] - 2s 20ms/step - loss: 1.0742 - accuracy: 0.6215 - val_loss: 1.1292 - val_accuracy: 0.6083
# Epoch 12/128
# 79/79 [==============================] - 2s 20ms/step - loss: 1.0258 - accuracy: 0.6460 - val_loss: 1.1100 - val_accuracy: 0.6116
# Epoch 13/128
# 79/79 [==============================] - 2s 20ms/step - loss: 1.0119 - accuracy: 0.6457 - val_loss: 1.0943 - val_accuracy: 0.6168
# Epoch 14/128
# 79/79 [==============================] - 2s 20ms/step - loss: 1.0055 - accuracy: 0.6488 - val_loss: 1.0821 - val_accuracy: 0.6226
# Epoch 15/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.9674 - accuracy: 0.6627 - val_loss: 1.0810 - val_accuracy: 0.6286
# Epoch 16/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.9556 - accuracy: 0.6690 - val_loss: 1.0964 - val_accuracy: 0.6204
# Epoch 17/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.9472 - accuracy: 0.6704 - val_loss: 1.0308 - val_accuracy: 0.6476
# Epoch 18/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.9189 - accuracy: 0.6779 - val_loss: 1.0452 - val_accuracy: 0.6374
# Epoch 19/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8980 - accuracy: 0.6871 - val_loss: 1.0122 - val_accuracy: 0.6527
# Epoch 20/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8933 - accuracy: 0.6921 - val_loss: 0.9862 - val_accuracy: 0.6615
# Epoch 21/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8845 - accuracy: 0.6948 - val_loss: 1.0231 - val_accuracy: 0.6471
# Epoch 22/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8597 - accuracy: 0.7025 - val_loss: 1.0634 - val_accuracy: 0.6333
# Epoch 23/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8629 - accuracy: 0.7005 - val_loss: 0.9875 - val_accuracy: 0.6652
# Epoch 24/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8344 - accuracy: 0.7134 - val_loss: 0.9740 - val_accuracy: 0.6714
# Epoch 25/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8259 - accuracy: 0.7156 - val_loss: 1.0164 - val_accuracy: 0.6533
# Epoch 26/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8238 - accuracy: 0.7153 - val_loss: 1.0788 - val_accuracy: 0.6342
# Epoch 27/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8241 - accuracy: 0.7160 - val_loss: 0.9957 - val_accuracy: 0.6603
# Epoch 28/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7980 - accuracy: 0.7226 - val_loss: 0.9667 - val_accuracy: 0.6699
# Epoch 29/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7820 - accuracy: 0.7328 - val_loss: 0.9609 - val_accuracy: 0.6722
# Epoch 30/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7787 - accuracy: 0.7283 - val_loss: 1.0287 - val_accuracy: 0.6495
# Epoch 31/128
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7849 - accuracy: 0.7292 - val_loss: 0.9722 - val_accuracy: 0.6734
# Epoch 32/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7447 - accuracy: 0.7433 - val_loss: 1.0183 - val_accuracy: 0.6606
# Epoch 33/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7502 - accuracy: 0.7432 - val_loss: 0.9578 - val_accuracy: 0.6749
# Epoch 34/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7415 - accuracy: 0.7455 - val_loss: 0.9645 - val_accuracy: 0.6735
# Epoch 35/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7344 - accuracy: 0.7487 - val_loss: 1.0268 - val_accuracy: 0.6590
# Epoch 36/128
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7170 - accuracy: 0.7533 - val_loss: 0.9525 - val_accuracy: 0.6791
# Epoch 37/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6967 - accuracy: 0.7627 - val_loss: 0.9730 - val_accuracy: 0.6767
# Epoch 38/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7016 - accuracy: 0.7582 - val_loss: 0.9553 - val_accuracy: 0.6790
# Epoch 39/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6917 - accuracy: 0.7595 - val_loss: 0.9729 - val_accuracy: 0.6788
# Epoch 40/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6678 - accuracy: 0.7709 - val_loss: 0.9650 - val_accuracy: 0.6802
# Epoch 41/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6684 - accuracy: 0.7711 - val_loss: 0.9650 - val_accuracy: 0.6826
# Epoch 42/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6656 - accuracy: 0.7694 - val_loss: 0.9432 - val_accuracy: 0.6849
# Epoch 43/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6585 - accuracy: 0.7722 - val_loss: 0.9626 - val_accuracy: 0.6821
# Epoch 44/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6507 - accuracy: 0.7747 - val_loss: 0.9563 - val_accuracy: 0.6844
# Epoch 45/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6388 - accuracy: 0.7828 - val_loss: 0.9813 - val_accuracy: 0.6803
# Epoch 46/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6517 - accuracy: 0.7750 - val_loss: 0.9510 - val_accuracy: 0.6878
# Epoch 47/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6174 - accuracy: 0.7893 - val_loss: 0.9581 - val_accuracy: 0.6862
# Epoch 48/128
# 79/79 [==============================] - 2s 19ms/step - loss: 0.6104 - accuracy: 0.7923 - val_loss: 0.9958 - val_accuracy: 0.6732
# Epoch 49/128
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6235 - accuracy: 0.7840 - val_loss: 1.0191 - val_accuracy: 0.6723
# Epoch 50/128
# 79/79 [==============================] - 2s 19ms/step - loss: 0.6211 - accuracy: 0.7850 - val_loss: 0.9595 - val_accuracy: 0.6867
# Epoch 51/128
# 79/79 [==============================] - 2s 19ms/step - loss: 0.5793 - accuracy: 0.8019 - val_loss: 0.9785 - val_accuracy: 0.6821

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:01:23.888265

# %% [markdown]
# ## 6. Results Evaluation
#
# Let's obtain a graph of how the error and accuracy evolve at each epoch in the training and validation data.

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 67.880

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# The cost we can see that it is stable and it is at epoch 15 that it is fixed at a value. Also the accuracy dances around 0.10. We can't say that it is a very good model.
#
# Let's see what kind of predictions I'm getting on the test set (let's paint the images and their classifications)

# %%
predictions = model.predict(x_test)

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# We draw the first images, with the predictions and their real values (a total of 20 images, so as not to abuse your laptops).
#
# We color the correct predictions in blue and the failures in red. But first I have printed the labels so that we have a reference to the graph.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
