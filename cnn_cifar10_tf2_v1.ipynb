# %% [markdown]
# ## 1. Import Libraries

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

# %% [markdown]
# ## 2. Neural Newtork Architecture

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(
    filters=32, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(32, activation="relu"))
model.add(ks.layers.Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                131104
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 150,826
# Trainable params: 150,826
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Cost function

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Data Preparation
#
# We load the CIFAR10 dataset directly from Keras. Those are already split in train and test.
#
#
# **Important:**
# > The neural network requires for the inputs to be real numbers. We can simply achieve this by divinding the values inside the matrices by 255.0.

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %%
# Let's plot a sample of the images

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# When we add convolutions, we need to preprocess the data, because **convolution is for an array of 4 fields** (more like "images"), not an array of 3 dimensions as the datasets for train, test and validation. So we need to **.reshape()**.
#
# That's why, when you exit the convolution, you have to flatten the matrices, because the FullDense layers expect arrays, not matrices!

# %%
# Let's validate the results
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# ## 5. Training
#
# Note that we have to train against the data converted to the format expected by the Convolution.
#
# We will start with 30 epochs, that is to say, 30 complete passes of the dataset (which in turn will be with mini-batches internally, setting the batches to 64 elements.
#
# The .fit() method allows us to define if we have several CPUs, GPUs, and if we want to validate data at each end of epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, epochs=64, 
                    use_multiprocessing=False, batch_size= 512, 
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/64
# 79/79 [==============================] - 5s 27ms/step - loss: 2.0981 - accuracy: 0.2173 - val_loss: 1.7796 - val_accuracy: 0.3469
# Epoch 2/64
# 79/79 [==============================] - 2s 20ms/step - loss: 1.6072 - accuracy: 0.4225 - val_loss: 1.4242 - val_accuracy: 0.4945
# Epoch 3/64
# 79/79 [==============================] - 2s 19ms/step - loss: 1.4035 - accuracy: 0.4973 - val_loss: 1.4623 - val_accuracy: 0.4902
# Epoch 4/64
# 79/79 [==============================] - 2s 20ms/step - loss: 1.3353 - accuracy: 0.5288 - val_loss: 1.2669 - val_accuracy: 0.5555
# Epoch 5/64
# 79/79 [==============================] - 2s 19ms/step - loss: 1.2427 - accuracy: 0.5590 - val_loss: 1.2273 - val_accuracy: 0.5721
# Epoch 6/64
# 79/79 [==============================] - 2s 20ms/step - loss: 1.1942 - accuracy: 0.5759 - val_loss: 1.1912 - val_accuracy: 0.5776
# Epoch 7/64
# 79/79 [==============================] - 2s 19ms/step - loss: 1.1443 - accuracy: 0.5951 - val_loss: 1.1356 - val_accuracy: 0.6095
# Epoch 8/64
# 79/79 [==============================] - 2s 19ms/step - loss: 1.1157 - accuracy: 0.6102 - val_loss: 1.1121 - val_accuracy: 0.6148
# Epoch 9/64
# 79/79 [==============================] - 2s 20ms/step - loss: 1.0797 - accuracy: 0.6220 - val_loss: 1.0903 - val_accuracy: 0.6231
# Epoch 10/64
# 79/79 [==============================] - 2s 19ms/step - loss: 1.0606 - accuracy: 0.6291 - val_loss: 1.1269 - val_accuracy: 0.6054
# Epoch 11/64
# 79/79 [==============================] - 2s 20ms/step - loss: 1.0390 - accuracy: 0.6350 - val_loss: 1.0828 - val_accuracy: 0.6226
# Epoch 12/64
# 79/79 [==============================] - 2s 20ms/step - loss: 1.0335 - accuracy: 0.6400 - val_loss: 1.0694 - val_accuracy: 0.6302
# Epoch 13/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.9927 - accuracy: 0.6540 - val_loss: 1.0020 - val_accuracy: 0.6526
# Epoch 14/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.9715 - accuracy: 0.6594 - val_loss: 1.0071 - val_accuracy: 0.6501
# Epoch 15/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.9540 - accuracy: 0.6699 - val_loss: 0.9947 - val_accuracy: 0.6518
# Epoch 16/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.9258 - accuracy: 0.6744 - val_loss: 0.9954 - val_accuracy: 0.6522
# Epoch 17/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.9262 - accuracy: 0.6792 - val_loss: 0.9539 - val_accuracy: 0.6713
# Epoch 18/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8958 - accuracy: 0.6892 - val_loss: 0.9444 - val_accuracy: 0.6735
# Epoch 19/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8924 - accuracy: 0.6892 - val_loss: 0.9476 - val_accuracy: 0.6756
# Epoch 20/64
# 79/79 [==============================] - 2s 19ms/step - loss: 0.8899 - accuracy: 0.6891 - val_loss: 0.9164 - val_accuracy: 0.6867
# Epoch 21/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8644 - accuracy: 0.7001 - val_loss: 0.9470 - val_accuracy: 0.6706
# Epoch 22/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8611 - accuracy: 0.6982 - val_loss: 0.9314 - val_accuracy: 0.6768
# Epoch 23/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8432 - accuracy: 0.7052 - val_loss: 0.9121 - val_accuracy: 0.6864
# Epoch 24/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8346 - accuracy: 0.7120 - val_loss: 0.9158 - val_accuracy: 0.6851
# Epoch 25/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8378 - accuracy: 0.7081 - val_loss: 0.8969 - val_accuracy: 0.6921
# Epoch 26/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8090 - accuracy: 0.7190 - val_loss: 0.9326 - val_accuracy: 0.6757
# Epoch 27/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8200 - accuracy: 0.7141 - val_loss: 0.8762 - val_accuracy: 0.6996
# Epoch 28/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7951 - accuracy: 0.7225 - val_loss: 0.8919 - val_accuracy: 0.6875
# Epoch 29/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7894 - accuracy: 0.7237 - val_loss: 0.8803 - val_accuracy: 0.6984
# Epoch 30/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7839 - accuracy: 0.7278 - val_loss: 0.8647 - val_accuracy: 0.7034
# Epoch 31/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7714 - accuracy: 0.7333 - val_loss: 0.8811 - val_accuracy: 0.6973
# Epoch 32/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7646 - accuracy: 0.7306 - val_loss: 0.8743 - val_accuracy: 0.6992
# Epoch 33/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7530 - accuracy: 0.7417 - val_loss: 0.9091 - val_accuracy: 0.6847
# Epoch 34/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7403 - accuracy: 0.7437 - val_loss: 0.9163 - val_accuracy: 0.6811
# Epoch 35/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7584 - accuracy: 0.7350 - val_loss: 0.8646 - val_accuracy: 0.7026
# Epoch 36/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7385 - accuracy: 0.7427 - val_loss: 0.8457 - val_accuracy: 0.7128
# Epoch 37/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7168 - accuracy: 0.7547 - val_loss: 0.8519 - val_accuracy: 0.7089
# Epoch 38/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7293 - accuracy: 0.7480 - val_loss: 0.8620 - val_accuracy: 0.7056
# Epoch 39/64
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7181 - accuracy: 0.7496 - val_loss: 0.8471 - val_accuracy: 0.7093
# Epoch 40/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7138 - accuracy: 0.7510 - val_loss: 0.8448 - val_accuracy: 0.7104
# Epoch 41/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6932 - accuracy: 0.7581 - val_loss: 0.8262 - val_accuracy: 0.7193
# Epoch 42/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6854 - accuracy: 0.7611 - val_loss: 0.8527 - val_accuracy: 0.7116
# Epoch 43/64
# 79/79 [==============================] - 2s 19ms/step - loss: 0.6828 - accuracy: 0.7653 - val_loss: 0.8547 - val_accuracy: 0.7047
# Epoch 44/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6710 - accuracy: 0.7655 - val_loss: 0.8412 - val_accuracy: 0.7112
# Epoch 45/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6820 - accuracy: 0.7612 - val_loss: 0.8450 - val_accuracy: 0.7131
# Epoch 46/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6799 - accuracy: 0.7635 - val_loss: 0.8607 - val_accuracy: 0.7120
# Epoch 47/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6767 - accuracy: 0.7648 - val_loss: 0.8568 - val_accuracy: 0.7061
# Epoch 48/64
# 79/79 [==============================] - 2s 19ms/step - loss: 0.6718 - accuracy: 0.7662 - val_loss: 0.8171 - val_accuracy: 0.7233
# Epoch 49/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6585 - accuracy: 0.7722 - val_loss: 0.8199 - val_accuracy: 0.7217
# Epoch 50/64
# 79/79 [==============================] - 2s 19ms/step - loss: 0.6464 - accuracy: 0.7744 - val_loss: 0.8162 - val_accuracy: 0.7270
# Epoch 51/64
# 79/79 [==============================] - 2s 19ms/step - loss: 0.6344 - accuracy: 0.7798 - val_loss: 0.8163 - val_accuracy: 0.7253
# Epoch 52/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6379 - accuracy: 0.7773 - val_loss: 0.8259 - val_accuracy: 0.7224
# Epoch 53/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6383 - accuracy: 0.7762 - val_loss: 0.8235 - val_accuracy: 0.7186
# Epoch 54/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6314 - accuracy: 0.7761 - val_loss: 0.8328 - val_accuracy: 0.7219
# Epoch 55/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6172 - accuracy: 0.7851 - val_loss: 0.8029 - val_accuracy: 0.7295
# Epoch 56/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6110 - accuracy: 0.7845 - val_loss: 0.8026 - val_accuracy: 0.7313
# Epoch 57/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6104 - accuracy: 0.7869 - val_loss: 0.8301 - val_accuracy: 0.7232
# Epoch 58/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6102 - accuracy: 0.7863 - val_loss: 0.8010 - val_accuracy: 0.7344
# Epoch 59/64
# 79/79 [==============================] - 2s 19ms/step - loss: 0.5954 - accuracy: 0.7936 - val_loss: 0.8188 - val_accuracy: 0.7270
# Epoch 60/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.5989 - accuracy: 0.7900 - val_loss: 0.8536 - val_accuracy: 0.7106
# Epoch 61/64
# 79/79 [==============================] - 2s 19ms/step - loss: 0.6156 - accuracy: 0.7839 - val_loss: 0.8188 - val_accuracy: 0.7244
# Epoch 62/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6039 - accuracy: 0.7898 - val_loss: 0.7970 - val_accuracy: 0.7361
# Epoch 63/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.5808 - accuracy: 0.7929 - val_loss: 0.8104 - val_accuracy: 0.7292
# Epoch 64/64
# 79/79 [==============================] - 2s 20ms/step - loss: 0.5786 - accuracy: 0.7958 - val_loss: 0.7980 - val_accuracy: 0.7344

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:01:43.266983

# %% [markdown]
# ## 6. Results Evaluation
#
# Let's obtain a graph of how the error and accuracy evolve at each epoch in the training and validation data.

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 73.610

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# The cost we can see that it is stable and it is at epoch 15 that it is fixed at a value. Also the accuracy dances around 0.10. We can't say that it is a very good model.
#
# Let's see what kind of predictions I'm getting on the test set (let's paint the images and their classifications)

# %%
predictions = model.predict(x_test)

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# We draw the first images, with the predictions and their real values (a total of 20 images, so as not to abuse your laptops).
#
# We color the correct predictions in blue and the failures in red. But first I have printed the labels so that we have a reference to the graph.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
