# %% [markdown]
# ## 1. Import Libraries

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## 2. Neural Newtork Architecture

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.3))


model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Conv2D(
    filters=32, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=32, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.3))


model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(512, activation="relu"))
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(512, activation="relu"))
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 128)       3584
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 128)       147584
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        73792
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 32)          18464
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 32)          9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               262656
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,004,554
# Trainable params: 1,004,554
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Cost function

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Data Preparation
#
# We load the CIFAR10 dataset directly from Keras. Those are already split in train and test.
#
#
# **Important:**
# > The neural network requires for the inputs to be real numbers. We can simply achieve this by divinding the values inside the matrices by 255.0.

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %%
# Let's plot a sample of the images

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# When we add convolutions, we need to preprocess the data, because **convolution is for an array of 4 fields** (more like "images"), not an array of 3 dimensions as the datasets for train, test and validation. So we need to **.reshape()**.
#
# That's why, when you exit the convolution, you have to flatten the matrices, because the FullDense layers expect arrays, not matrices!

# %%
# Let's validate the results
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# # 4. Early Stopping

# %%
callback_loss = EarlyStopping(monitor="val_loss", patience=15)
callback_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)

# %% [markdown]
# ## 5. Training
#
# Note that we have to train against the data converted to the format expected by the Convolution.
#
# We will start with 30 epochs, that is to say, 30 complete passes of the dataset (which in turn will be with mini-batches internally, setting the batches to 64 elements.
#
# The .fit() method allows us to define if we have several CPUs, GPUs, and if we want to validate data at each end of epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, 
                    epochs=300, 
                    use_multiprocessing=False, 
                    batch_size= 512, 
                    callbacks=[callback_accuracy, callback_loss],
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/300
# 79/79 [==============================] - 24s 225ms/step - loss: 2.2134 - accuracy: 0.1543 - val_loss: 1.9057 - val_accuracy: 0.2897
# Epoch 2/300
# 79/79 [==============================] - 15s 196ms/step - loss: 1.8140 - accuracy: 0.3124 - val_loss: 1.6736 - val_accuracy: 0.3836
# Epoch 3/300
# 79/79 [==============================] - 15s 195ms/step - loss: 1.5901 - accuracy: 0.4105 - val_loss: 1.3777 - val_accuracy: 0.4904
# Epoch 4/300
# 79/79 [==============================] - 15s 194ms/step - loss: 1.4189 - accuracy: 0.4733 - val_loss: 1.3178 - val_accuracy: 0.5175
# Epoch 5/300
# 79/79 [==============================] - 15s 194ms/step - loss: 1.2789 - accuracy: 0.5377 - val_loss: 1.1942 - val_accuracy: 0.5716
# Epoch 6/300
# 79/79 [==============================] - 15s 195ms/step - loss: 1.1871 - accuracy: 0.5693 - val_loss: 1.0847 - val_accuracy: 0.6099
# Epoch 7/300
# 79/79 [==============================] - 15s 195ms/step - loss: 1.1058 - accuracy: 0.6021 - val_loss: 0.9463 - val_accuracy: 0.6600
# Epoch 8/300
# 79/79 [==============================] - 15s 195ms/step - loss: 1.0218 - accuracy: 0.6359 - val_loss: 0.8895 - val_accuracy: 0.6791
# Epoch 9/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.9595 - accuracy: 0.6590 - val_loss: 0.9055 - val_accuracy: 0.6775
# Epoch 10/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.9252 - accuracy: 0.6731 - val_loss: 0.7853 - val_accuracy: 0.7174
# Epoch 11/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.8544 - accuracy: 0.6948 - val_loss: 0.7816 - val_accuracy: 0.7220
# Epoch 12/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.8097 - accuracy: 0.7163 - val_loss: 0.8066 - val_accuracy: 0.7170
# Epoch 13/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.7933 - accuracy: 0.7176 - val_loss: 0.7549 - val_accuracy: 0.7371
# Epoch 14/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.7430 - accuracy: 0.7391 - val_loss: 0.6871 - val_accuracy: 0.7562
# Epoch 15/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.7356 - accuracy: 0.7386 - val_loss: 0.7141 - val_accuracy: 0.7518
# Epoch 16/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.7120 - accuracy: 0.7497 - val_loss: 0.6717 - val_accuracy: 0.7660
# Epoch 17/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.6868 - accuracy: 0.7560 - val_loss: 0.6797 - val_accuracy: 0.7615
# Epoch 18/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.6656 - accuracy: 0.7650 - val_loss: 0.7282 - val_accuracy: 0.7529
# Epoch 19/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.6498 - accuracy: 0.7762 - val_loss: 0.6354 - val_accuracy: 0.7776
# Epoch 20/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.6229 - accuracy: 0.7826 - val_loss: 0.6339 - val_accuracy: 0.7816
# Epoch 21/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.5955 - accuracy: 0.7922 - val_loss: 0.6195 - val_accuracy: 0.7855
# Epoch 22/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.5848 - accuracy: 0.7970 - val_loss: 0.6244 - val_accuracy: 0.7851
# Epoch 23/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.5698 - accuracy: 0.8023 - val_loss: 0.6217 - val_accuracy: 0.7853
# Epoch 24/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.5589 - accuracy: 0.8023 - val_loss: 0.6185 - val_accuracy: 0.7882
# Epoch 25/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.5222 - accuracy: 0.8179 - val_loss: 0.6022 - val_accuracy: 0.7946
# Epoch 26/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.5473 - accuracy: 0.8102 - val_loss: 0.6190 - val_accuracy: 0.7929
# Epoch 27/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.5377 - accuracy: 0.8102 - val_loss: 0.6195 - val_accuracy: 0.7924
# Epoch 28/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.4990 - accuracy: 0.8251 - val_loss: 0.6023 - val_accuracy: 0.7975
# Epoch 29/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.4912 - accuracy: 0.8259 - val_loss: 0.5826 - val_accuracy: 0.8031
# Epoch 30/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.4766 - accuracy: 0.8321 - val_loss: 0.5747 - val_accuracy: 0.8089
# Epoch 31/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.4645 - accuracy: 0.8384 - val_loss: 0.6165 - val_accuracy: 0.7928
# Epoch 32/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.4567 - accuracy: 0.8391 - val_loss: 0.5917 - val_accuracy: 0.8035
# Epoch 33/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.4596 - accuracy: 0.8396 - val_loss: 0.5859 - val_accuracy: 0.8045
# Epoch 34/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.4591 - accuracy: 0.8399 - val_loss: 0.5440 - val_accuracy: 0.8144
# Epoch 35/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.4337 - accuracy: 0.8472 - val_loss: 0.5825 - val_accuracy: 0.8040
# Epoch 36/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.4351 - accuracy: 0.8477 - val_loss: 0.5628 - val_accuracy: 0.8138
# Epoch 37/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.4218 - accuracy: 0.8496 - val_loss: 0.5959 - val_accuracy: 0.8053
# Epoch 38/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.4244 - accuracy: 0.8513 - val_loss: 0.5425 - val_accuracy: 0.8195
# Epoch 39/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.4275 - accuracy: 0.8511 - val_loss: 0.5649 - val_accuracy: 0.8157
# Epoch 40/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.4141 - accuracy: 0.8557 - val_loss: 0.5417 - val_accuracy: 0.8199
# Epoch 41/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.3903 - accuracy: 0.8621 - val_loss: 0.5675 - val_accuracy: 0.8176
# Epoch 42/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.3874 - accuracy: 0.8632 - val_loss: 0.5419 - val_accuracy: 0.8249
# Epoch 43/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.3745 - accuracy: 0.8683 - val_loss: 0.5587 - val_accuracy: 0.8174
# Epoch 44/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.3785 - accuracy: 0.8687 - val_loss: 0.5310 - val_accuracy: 0.8243
# Epoch 45/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.3680 - accuracy: 0.8693 - val_loss: 0.5423 - val_accuracy: 0.8274
# Epoch 46/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.3553 - accuracy: 0.8769 - val_loss: 0.5688 - val_accuracy: 0.8190
# Epoch 47/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.4031 - accuracy: 0.8616 - val_loss: 0.5530 - val_accuracy: 0.8223
# Epoch 48/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.3508 - accuracy: 0.8761 - val_loss: 0.5529 - val_accuracy: 0.8250
# Epoch 49/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.3407 - accuracy: 0.8794 - val_loss: 0.5681 - val_accuracy: 0.8199
# Epoch 50/300
# 79/79 [==============================] - 15s 195ms/step - loss: 0.3437 - accuracy: 0.8800 - val_loss: 0.5431 - val_accuracy: 0.8253
# Epoch 51/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.3448 - accuracy: 0.8806 - val_loss: 0.5744 - val_accuracy: 0.8262
# Epoch 52/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.3402 - accuracy: 0.8838 - val_loss: 0.5888 - val_accuracy: 0.8170
# Epoch 53/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.3340 - accuracy: 0.8808 - val_loss: 0.6116 - val_accuracy: 0.8138
# Epoch 54/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.3213 - accuracy: 0.8880 - val_loss: 0.5891 - val_accuracy: 0.8206
# Epoch 55/300
# 79/79 [==============================] - 15s 194ms/step - loss: 0.3187 - accuracy: 0.8880 - val_loss: 0.6045 - val_accuracy: 0.8213

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:14:14.017705

# %% [markdown]
# ## 6. Results Evaluation
#
# Let's obtain a graph of how the error and accuracy evolve at each epoch in the training and validation data.

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 81.810

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# The cost we can see that it is stable and it is at epoch 15 that it is fixed at a value. Also the accuracy dances around 0.10. We can't say that it is a very good model.
#
# Let's see what kind of predictions I'm getting on the test set (let's paint the images and their classifications)

# %%
predictions = model.predict(x_test)

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# We draw the first images, with the predictions and their real values (a total of 20 images, so as not to abuse your laptops).
#
# We color the correct predictions in blue and the failures in red. But first I have printed the labels so that we have a reference to the graph.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
