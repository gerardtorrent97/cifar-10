# %% [markdown]
# ## 1. Import Libraries

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## 2. Neural Newtork Architecture

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))


model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.5))



model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(1024, activation="relu"))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              4195328
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 5,941,066
# Trainable params: 5,941,066
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Cost function

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Data Preparation
#
# We load the CIFAR10 dataset directly from Keras. Those are already split in train and test.
#
#
# **Important:**
# > The neural network requires for the inputs to be real numbers. We can simply achieve this by divinding the values inside the matrices by 255.0.

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %%
# Let's plot a sample of the images

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# When we add convolutions, we need to preprocess the data, because **convolution is for an array of 4 fields** (more like "images"), not an array of 3 dimensions as the datasets for train, test and validation. So we need to **.reshape()**.
#
# That's why, when you exit the convolution, you have to flatten the matrices, because the FullDense layers expect arrays, not matrices!

# %%
# Let's validate the results
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# # 4. Early Stopping

# %%
callback_loss = EarlyStopping(monitor="val_loss", patience=15)
callback_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)

# %% [markdown]
# ## 5. Training
#
# Note that we have to train against the data converted to the format expected by the Convolution.
#
# We will start with 30 epochs, that is to say, 30 complete passes of the dataset (which in turn will be with mini-batches internally, setting the batches to 64 elements.
#
# The .fit() method allows us to define if we have several CPUs, GPUs, and if we want to validate data at each end of epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, 
                    epochs=300, 
                    use_multiprocessing=False, 
                    batch_size= 512, 
                    callbacks=[callback_accuracy, callback_loss],
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/300
# 79/79 [==============================] - 44s 124ms/step - loss: 2.0911 - accuracy: 0.2147 - val_loss: 2.2243 - val_accuracy: 0.2119
# Epoch 2/300
# 79/79 [==============================] - 8s 104ms/step - loss: 1.7374 - accuracy: 0.3449 - val_loss: 1.7870 - val_accuracy: 0.3558
# Epoch 3/300
# 79/79 [==============================] - 8s 105ms/step - loss: 1.4963 - accuracy: 0.4498 - val_loss: 1.3715 - val_accuracy: 0.4986
# Epoch 4/300
# 79/79 [==============================] - 8s 105ms/step - loss: 1.3281 - accuracy: 0.5132 - val_loss: 1.2128 - val_accuracy: 0.5603
# Epoch 5/300
# 79/79 [==============================] - 8s 106ms/step - loss: 1.2281 - accuracy: 0.5530 - val_loss: 1.2507 - val_accuracy: 0.5595
# Epoch 6/300
# 79/79 [==============================] - 8s 106ms/step - loss: 1.1302 - accuracy: 0.5944 - val_loss: 1.2781 - val_accuracy: 0.5660
# Epoch 7/300
# 79/79 [==============================] - 8s 107ms/step - loss: 1.0694 - accuracy: 0.6166 - val_loss: 1.0104 - val_accuracy: 0.6378
# Epoch 8/300
# 79/79 [==============================] - 8s 107ms/step - loss: 0.9817 - accuracy: 0.6483 - val_loss: 0.9724 - val_accuracy: 0.6589
# Epoch 9/300
# 79/79 [==============================] - 8s 107ms/step - loss: 0.9225 - accuracy: 0.6718 - val_loss: 1.0145 - val_accuracy: 0.6568
# Epoch 10/300
# 79/79 [==============================] - 8s 107ms/step - loss: 0.8693 - accuracy: 0.6888 - val_loss: 0.8348 - val_accuracy: 0.7041
# Epoch 11/300
# 79/79 [==============================] - 9s 108ms/step - loss: 0.8266 - accuracy: 0.7061 - val_loss: 0.7800 - val_accuracy: 0.7228
# Epoch 12/300
# Epoch 32/300
# 79/79 [==============================] - 9s 111ms/step - loss: 0.4257 - accuracy: 0.8499 - val_loss: 0.5524 - val_accuracy: 0.8217
# Epoch 33/300
# 79/79 [==============================] - 9s 111ms/step - loss: 0.4079 - accuracy: 0.8536 - val_loss: 0.5504 - val_accuracy: 0.8196
# Epoch 34/300
# 79/79 [==============================] - 9s 111ms/step - loss: 0.4029 - accuracy: 0.8571 - val_loss: 0.5878 - val_accuracy: 0.8140
# Epoch 35/300
# 79/79 [==============================] - 9s 111ms/step - loss: 0.3979 - accuracy: 0.8581 - val_loss: 0.5326 - val_accuracy: 0.8296
# Epoch 36/300
# 79/79 [==============================] - 9s 111ms/step - loss: 0.3947 - accuracy: 0.8590 - val_loss: 0.5105 - val_accuracy: 0.8342
# Epoch 37/300
# 79/79 [==============================] - 9s 111ms/step - loss: 0.3756 - accuracy: 0.8669 - val_loss: 0.5293 - val_accuracy: 0.8288
# Epoch 38/300
# 79/79 [==============================] - 9s 111ms/step - loss: 0.3822 - accuracy: 0.8651 - val_loss: 0.5701 - val_accuracy: 0.8153
# Epoch 39/300
# 79/79 [==============================] - 9s 112ms/step - loss: 0.3722 - accuracy: 0.8684 - val_loss: 0.5127 - val_accuracy: 0.8302
# Epoch 40/300
# 79/79 [==============================] - 9s 111ms/step - loss: 0.3569 - accuracy: 0.8702 - val_loss: 0.5713 - val_accuracy: 0.8264
# Epoch 41/300
# 79/79 [==============================] - 9s 112ms/step - loss: 0.3643 - accuracy: 0.8693 - val_loss: 0.5704 - val_accuracy: 0.8185
# Epoch 42/300
# 79/79 [==============================] - 9s 111ms/step - loss: 0.3428 - accuracy: 0.8791 - val_loss: 0.5461 - val_accuracy: 0.8232
# Epoch 43/300
# 79/79 [==============================] - 9s 112ms/step - loss: 0.3432 - accuracy: 0.8778 - val_loss: 0.5748 - val_accuracy: 0.8201
# Epoch 44/300
# 79/79 [==============================] - 9s 112ms/step - loss: 0.3405 - accuracy: 0.8786 - val_loss: 0.5206 - val_accuracy: 0.8396
# Epoch 45/300
# 79/79 [==============================] - 9s 112ms/step - loss: 0.3424 - accuracy: 0.8782 - val_loss: 0.5882 - val_accuracy: 0.8181
# Epoch 46/300
# 79/79 [==============================] - 9s 112ms/step - loss: 0.3479 - accuracy: 0.8755 - val_loss: 0.5515 - val_accuracy: 0.8260
# Epoch 47/300
# 79/79 [==============================] - 9s 112ms/step - loss: 0.3237 - accuracy: 0.8849 - val_loss: 0.5481 - val_accuracy: 0.8284
# Epoch 48/300
# 79/79 [==============================] - 9s 112ms/step - loss: 0.3191 - accuracy: 0.8864 - val_loss: 0.5374 - val_accuracy: 0.8261
# Epoch 49/300
# 79/79 [==============================] - 9s 112ms/step - loss: 0.3165 - accuracy: 0.8858 - val_loss: 0.5157 - val_accuracy: 0.8397
# Epoch 50/300
# 79/79 [==============================] - 9s 112ms/step - loss: 0.3182 - accuracy: 0.8853 - val_loss: 0.5281 - val_accuracy: 0.8349
# Epoch 51/300
# 79/79 [==============================] - 9s 112ms/step - loss: 0.3018 - accuracy: 0.8911 - val_loss: 0.5140 - val_accuracy: 0.8390

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:07:58.305224

# %% [markdown]
# ## 6. Results Evaluation
#
# Let's obtain a graph of how the error and accuracy evolve at each epoch in the training and validation data.

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 82.950

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# The cost we can see that it is stable and it is at epoch 15 that it is fixed at a value. Also the accuracy dances around 0.10. We can't say that it is a very good model.
#
# Let's see what kind of predictions I'm getting on the test set (let's paint the images and their classifications)

# %%
predictions = model.predict(x_test)

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# We draw the first images, with the predictions and their real values (a total of 20 images, so as not to abuse your laptops).
#
# We color the correct predictions in blue and the failures in red. But first I have printed the labels so that we have a reference to the graph.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
