# %% [markdown]
# ## 1. Import Libraries

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## 2. Neural Newtork Architecture

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.35))

model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=128, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.35))


model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(
    filters=256, 
    kernel_size=(3, 3), 
    strides=1, 
    activation="relu", 
    padding="same", 
    input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(ks.layers.Dropout(0.35))



model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(512, activation="relu"))
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(512, activation="relu"))
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(512, activation="relu"))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               2097664
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 4,363,594
# Trainable params: 4,363,594
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Cost function

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Data Preparation
#
# We load the CIFAR10 dataset directly from Keras. Those are already split in train and test.
#
#
# **Important:**
# > The neural network requires for the inputs to be real numbers. We can simply achieve this by divinding the values inside the matrices by 255.0.

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %%
# Let's plot a sample of the images

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# When we add convolutions, we need to preprocess the data, because **convolution is for an array of 4 fields** (more like "images"), not an array of 3 dimensions as the datasets for train, test and validation. So we need to **.reshape()**.
#
# That's why, when you exit the convolution, you have to flatten the matrices, because the FullDense layers expect arrays, not matrices!

# %%
# Let's validate the results
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# # 4. Early Stopping

# %%
callback_loss = EarlyStopping(monitor="val_loss", patience=15)
callback_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)

# %% [markdown]
# ## 5. Training
#
# Note that we have to train against the data converted to the format expected by the Convolution.
#
# We will start with 30 epochs, that is to say, 30 complete passes of the dataset (which in turn will be with mini-batches internally, setting the batches to 64 elements.
#
# The .fit() method allows us to define if we have several CPUs, GPUs, and if we want to validate data at each end of epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, 
                    epochs=300, 
                    use_multiprocessing=False, 
                    batch_size= 512, 
                    callbacks=[callback_accuracy, callback_loss],
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/300
# 79/79 [==============================] - 25s 241ms/step - loss: 2.2624 - accuracy: 0.1262 - val_loss: 2.0065 - val_accuracy: 0.2113
# Epoch 2/300
# 79/79 [==============================] - 17s 212ms/step - loss: 1.9312 - accuracy: 0.2492 - val_loss: 1.8563 - val_accuracy: 0.3248
# Epoch 3/300
# 79/79 [==============================] - 17s 212ms/step - loss: 1.6686 - accuracy: 0.3672 - val_loss: 1.5401 - val_accuracy: 0.4350
# Epoch 4/300
# 79/79 [==============================] - 17s 212ms/step - loss: 1.4935 - accuracy: 0.4412 - val_loss: 1.2987 - val_accuracy: 0.5210
# Epoch 5/300
# 79/79 [==============================] - 17s 213ms/step - loss: 1.3532 - accuracy: 0.5027 - val_loss: 1.1751 - val_accuracy: 0.5776
# Epoch 6/300
# 79/79 [==============================] - 17s 212ms/step - loss: 1.2139 - accuracy: 0.5619 - val_loss: 1.1077 - val_accuracy: 0.6085
# Epoch 7/300
# 79/79 [==============================] - 17s 212ms/step - loss: 1.1170 - accuracy: 0.6051 - val_loss: 0.9746 - val_accuracy: 0.6591
# Epoch 8/300
# 79/79 [==============================] - 17s 212ms/step - loss: 1.0321 - accuracy: 0.6382 - val_loss: 0.9039 - val_accuracy: 0.6844
# Epoch 9/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.9696 - accuracy: 0.6550 - val_loss: 0.8676 - val_accuracy: 0.6941
# Epoch 10/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.9062 - accuracy: 0.6832 - val_loss: 0.9453 - val_accuracy: 0.6674
# Epoch 11/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.8660 - accuracy: 0.6987 - val_loss: 0.7609 - val_accuracy: 0.7320
# Epoch 12/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.8050 - accuracy: 0.7197 - val_loss: 0.7669 - val_accuracy: 0.7332
# Epoch 13/300
# 79/79 [==============================] - 17s 213ms/step - loss: 0.7701 - accuracy: 0.7339 - val_loss: 0.6948 - val_accuracy: 0.7589
# Epoch 14/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.7073 - accuracy: 0.7548 - val_loss: 0.7032 - val_accuracy: 0.7532
# Epoch 15/300
# 79/79 [==============================] - 17s 213ms/step - loss: 0.6908 - accuracy: 0.7659 - val_loss: 0.6741 - val_accuracy: 0.7689
# Epoch 16/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.6590 - accuracy: 0.7755 - val_loss: 0.6655 - val_accuracy: 0.7743
# Epoch 17/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.6314 - accuracy: 0.7813 - val_loss: 0.6636 - val_accuracy: 0.7680
# Epoch 18/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.5996 - accuracy: 0.7923 - val_loss: 0.6109 - val_accuracy: 0.7913
# Epoch 19/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.5837 - accuracy: 0.7992 - val_loss: 0.6521 - val_accuracy: 0.7827
# Epoch 20/300
# 79/79 [==============================] - 17s 213ms/step - loss: 0.5707 - accuracy: 0.8065 - val_loss: 0.6050 - val_accuracy: 0.7940
# Epoch 21/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.5492 - accuracy: 0.8139 - val_loss: 0.6190 - val_accuracy: 0.7926
# Epoch 22/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.5256 - accuracy: 0.8218 - val_loss: 0.5943 - val_accuracy: 0.8000
# Epoch 23/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.5082 - accuracy: 0.8245 - val_loss: 0.6368 - val_accuracy: 0.7875
# Epoch 24/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.4951 - accuracy: 0.8292 - val_loss: 0.5695 - val_accuracy: 0.8061
# Epoch 25/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.4690 - accuracy: 0.8393 - val_loss: 0.5679 - val_accuracy: 0.8114
# Epoch 26/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.4646 - accuracy: 0.8426 - val_loss: 0.5540 - val_accuracy: 0.8143
# Epoch 27/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.4279 - accuracy: 0.8538 - val_loss: 0.5453 - val_accuracy: 0.8189
# Epoch 28/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.4348 - accuracy: 0.8530 - val_loss: 0.6264 - val_accuracy: 0.8021
# Epoch 29/300
# 79/79 [==============================] - 17s 213ms/step - loss: 0.4201 - accuracy: 0.8547 - val_loss: 0.5741 - val_accuracy: 0.8141
# Epoch 30/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.4081 - accuracy: 0.8580 - val_loss: 0.5965 - val_accuracy: 0.8080
# Epoch 31/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.4087 - accuracy: 0.8599 - val_loss: 0.5972 - val_accuracy: 0.8097
# Epoch 32/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.3842 - accuracy: 0.8663 - val_loss: 0.5553 - val_accuracy: 0.8231
# Epoch 33/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.3712 - accuracy: 0.8711 - val_loss: 0.5652 - val_accuracy: 0.8243
# Epoch 34/300
# 79/79 [==============================] - 17s 213ms/step - loss: 0.3710 - accuracy: 0.8731 - val_loss: 0.5361 - val_accuracy: 0.8288
# Epoch 35/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.3593 - accuracy: 0.8808 - val_loss: 0.5670 - val_accuracy: 0.8232
# Epoch 36/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.3630 - accuracy: 0.8752 - val_loss: 0.5618 - val_accuracy: 0.8221
# Epoch 37/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.3383 - accuracy: 0.8872 - val_loss: 0.5920 - val_accuracy: 0.8146
# Epoch 38/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.3388 - accuracy: 0.8859 - val_loss: 0.5647 - val_accuracy: 0.8262
# Epoch 39/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.3306 - accuracy: 0.8869 - val_loss: 0.5658 - val_accuracy: 0.8273
# Epoch 40/300
# 79/79 [==============================] - 17s 213ms/step - loss: 0.3182 - accuracy: 0.8920 - val_loss: 0.5551 - val_accuracy: 0.8279
# Epoch 41/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.3245 - accuracy: 0.8900 - val_loss: 0.5641 - val_accuracy: 0.8232
# Epoch 42/300
# 79/79 [==============================] - 17s 213ms/step - loss: 0.3060 - accuracy: 0.8949 - val_loss: 0.5613 - val_accuracy: 0.8312
# Epoch 43/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.2979 - accuracy: 0.8970 - val_loss: 0.5690 - val_accuracy: 0.8280
# Epoch 44/300
# 79/79 [==============================] - 17s 213ms/step - loss: 0.3071 - accuracy: 0.8972 - val_loss: 0.5394 - val_accuracy: 0.8348
# Epoch 45/300
# 79/79 [==============================] - 17s 212ms/step - loss: 0.2927 - accuracy: 0.9005 - val_loss: 0.5504 - val_accuracy: 0.8347
# Epoch 46/300
# 79/79 [==============================] - 17s 213ms/step - loss: 0.2710 - accuracy: 0.9070 - val_loss: 0.5666 - val_accuracy: 0.8297
# Epoch 47/300
# 79/79 [==============================] - 17s 213ms/step - loss: 0.2802 - accuracy: 0.9029 - val_loss: 0.6244 - val_accuracy: 0.8241
# Epoch 48/300
# 79/79 [==============================] - 17s 213ms/step - loss: 0.2987 - accuracy: 0.9026 - val_loss: 0.5676 - val_accuracy: 0.8346
# Epoch 49/300
# 79/79 [==============================] - 17s 213ms/step - loss: 0.2770 - accuracy: 0.9074 - val_loss: 0.5669 - val_accuracy: 0.8279

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:13:50.369031

# %% [markdown]
# ## 6. Results Evaluation
#
# Let's obtain a graph of how the error and accuracy evolve at each epoch in the training and validation data.

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 81.900

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# The cost we can see that it is stable and it is at epoch 15 that it is fixed at a value. Also the accuracy dances around 0.10. We can't say that it is a very good model.
#
# Let's see what kind of predictions I'm getting on the test set (let's paint the images and their classifications)

# %%
predictions = model.predict(x_test)

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# We draw the first images, with the predictions and their real values (a total of 20 images, so as not to abuse your laptops).
#
# We color the correct predictions in blue and the failures in red. But first I have printed the labels so that we have a reference to the graph.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
